# %% [markdown]
# # 1. TRENDING STOCK SYMBOLS
#
# API domain: https://yfapi.net
# API path: /v1/finance/trending/{region}
#
# Pull data (extract) from yahoofinancials API (URL path is /v1/finance/trending/{region}).
# It returns 20 stock symbols based on the region in the URL.
#
# Uses your basic subscription API key obtained from yahoofinancials web site.
# Current region: US

# %%
# Import required modules
import pandas as pd

# %%
##  Ensure you have your own config.py file in same folder so you can import your api key
import requests
import pprint
from config import API_KEY

region_selected = "US"
url = "https://yfapi.net/v1/finance/trending/" + region_selected
## Alternate url
# url = "https://rest.yahoofinanceapi.com/v1/finance/trending/" + region_selected

# Credentials to include
headers = {
    'x-api-key': API_KEY
    }

# %%
## Make API request (no query string required for this API)
response1 = requests.request("GET", url, headers=headers).json()

# What does the response look like?  We will have to use indexing to get to the 'result' level
pprint.pprint(response1)
# Out:
# {'finance': {'error': None,
#              'result': [{'count': 20,
#                          'jobTimestamp': 1632154231475,
#                          'quotes': [{'symbol': 'TSLA'},
#                                     {'symbol': 'ZIVO'},
#                                     {'symbol': 'BTC-USD'},
#                                     {'symbol': '^DJI'},
#                                     {'symbol': '^VIX'},
#                                     {'symbol': 'EGRNY'},
#                                     {'symbol': 'EDSA'},
#                                     {'symbol': 'NVDA'},
#                                     {'symbol': 'AVIR'},
#                                     {'symbol': 'AMZN'},
#                                     {'symbol': '3333.HK'},
#                                     {'symbol': 'NWAU'},
#                                     {'symbol': 'BABA'},
#                                     {'symbol': 'NIO'},
#                                     {'symbol': 'ATER'},
#                                     {'symbol': 'VIVE'},
#                                     {'symbol': 'VSTM'},
#                                     {'symbol': '^GSPC'},
#                                     {'symbol': 'APRE'},
#                                     {'symbol': 'BRKS'}],
#                          'startInterval': 202109201500}]}}

# %%
# Check that 'error' was 'None'
# Query pulled 20 stock symbols in US.

# %%
## How many responses did we get?  Single result with multiple columns
len(response1['finance']['result'])
# Out:
# 1

# %%
## Parse through the resulting dictionary tree to get at the 'results'.  Look at only the first
##  result in order to see what columns we received.
response1['finance']['result'][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-59f6f726ea7f> in <module>
#       1 ## Parse through the resulting dictionary tree to get at the 'results'.  Look at only the first
#       2 ##  result in order to see what columns we received.
# ----> 3 response['finance']['result'][0]
#
# KeyError: 'finance'

# %%
# Create a new DataFrame from all the results in the dictionary
response1_df = pd.DataFrame(response1['finance']['result'])
response1_df.head()
# Out:
#    count                                             quotes   jobTimestamp  \
# 0     20  [{'symbol': 'TSLA'}, {'symbol': 'ZIVO'}, {'sym...  1632154231475
#
#    startInterval
# 0   202109201500

# %%
# Extraction of the quotes, timestamp, startInterval
start_interval = response1_df['startInterval']
start_interval
# Out:
# 0    202109201500
# Name: startInterval, dtype: int64

# %%
# Loop through each stock symbol retrieved. Use later in retrieving quote and detail
## Using 'for' loop
# stock_list=[]
# for stock in response1_df['quotes'][0]:
#     #print(stock['symbol'])
#     stock_list.append(stock['symbol'])
## Using list comprehension notation
# stock_list = [stock['symbol'] for stock in response1_df['quotes'][0]]
stock_list = [stock['symbol'] for stock in response1_df['quotes'][0]]
stock_list
# Out:
# ['TSLA',
#  'ZIVO',
#  'BTC-USD',
#  '^DJI',
#  '^VIX',
#  'EGRNY',
#  'EDSA',
#  'NVDA',
#  'AVIR',
#  'AMZN',
#  '3333.HK',
#  'NWAU',
#  'BABA',
#  'NIO',
#  'ATER',
#  'VIVE',
#  'VSTM',
#  '^GSPC',
#  'APRE',
#  'BRKS']

# %%
# The quote API query wants the list of symbols as a single comma separated string 
#  with no spaces.  Max is 10 per request.
query_string=''
for stock in stock_list:
    query_string += f"{stock},"
query_string = query_string.rstrip(',')
query_string
# Out:
# 'TSLA,ZIVO,BTC-USD,^DJI,^VIX,EGRNY,EDSA,NVDA,AVIR,AMZN,3333.HK,NWAU,BABA,NIO,ATER,VIVE,VSTM,^GSPC,APRE,BRKS'

# %%
# For now, get the first 10 and run the quote API
query_string=''
for i in range(10):
    query_string += f"{response1_df['quotes'][0][i]['symbol']},"
query_string = query_string.rstrip(',')
query_string
# Out:
# 'TSLA,ZIVO,BTC-USD,^DJI,^VIX,EGRNY,EDSA,NVDA,AVIR,AMZN'

# %% [markdown]
# # 2. REAL TIME QUOTE DATA
#
# API domain: https://yfapi.net
# API path: /v6/finance/quote
# API variables:  querystring  {"symbols" : "string1,string2,string3,..."}
#
# Pull data (extract) from yahoofinancials API (URL path is /v6/finance/quote) with "symbols" set to comma-separated list of up to 10 stock symbols at a time.
#
# Use the query_string of 10 stock symbols.

# %%
## Query of /v6/finance/quote API

url = "https://yfapi.net/v6/finance/quote"
## Alternate url
# url = "https://rest.yahoofinanceapi.com/v6/finance/quote"

## Warning: no space between symbols
querystring = {"symbols" : query_string}

# Credentials to include
headers = {
    'x-api-key': API_KEY
    }

# %%
## Make API request (query string required for this API)
response2 = requests.request("GET", url, headers=headers, params=querystring).json()

# What does the response look like?  We will have to use indexing to get to the 'result' level
pprint.pprint(response2)
# Out:
# {'quoteResponse': {'error': None,
#                    'result': [{'ask': 729.65,
#                                'askSize': 10,
#                                'averageAnalystRating': '2.6 - Hold',
#                                'averageDailyVolume10Day': 19009816,
#                                'averageDailyVolume3Month': 19828396,
#                                'bid': 729.1,
#                                'bidSize': 10,
#                                'bookValue': 25.207,
#                                'currency': 'USD',
#                                'displayName': 'Tesla',
#                                'earningsTimestamp': 1627315620,
#                                'earningsTimestampEnd': 1635163200,
#                                'earningsTimestampStart': 1634641140,
#                                'epsCurrentYear': 5.26,
#                                'epsForward': 7.07,
#                                'epsTrailingTwelveMonths': 1.897,
#                                'esgPopulated': False,
#                                'exchange': 'NMS',
#                                'exchangeDataDelayedBy': 0,
#                                'exchangeTimezoneName': 'America/New_York',
#                                'exchangeTimezoneShortName': 'EDT',
#                                'fiftyDayAverage': 719.79767,
#                                'fiftyDayAverageChange': 10.372314,
#                                'fiftyDayAverageChangePercent': 0.014410042,
#                                'fiftyTwoWeekHigh': 900.4,
#                                'fiftyTwoWeekHighChange': -170.23004,
#                                'fiftyTwoWeekHighChangePercent': -0.18906046,
#                                'fiftyTwoWeekLow': 351.3,
#                                'fiftyTwoWeekLowChange': 378.87,
#                                'fiftyTwoWeekLowChangePercent': 1.07848,
#                                'fiftyTwoWeekRange': '351.3 - 900.4',
#                                'financialCurrency': 'USD',
#                                'firstTradeDateMilliseconds': 1277818200000,
#                                'forwardPE': 103.27722,
#                                'fullExchangeName': 'NasdaqGS',
#                                'gmtOffSetMilliseconds': -14400000,
#                                'language': 'en-US',
#                                'longName': 'Tesla, Inc.',
#                                'market': 'us_market',
#                                'marketCap': 731462369280,
#                                'marketState': 'POST',
#                                'messageBoardId': 'finmb_27444752',
#                                'postMarketChange': -0.19000244,
#                                'postMarketChangePercent': -0.026021672,
#                                'postMarketPrice': 729.98,
#                                'postMarketTime': 1632170862,
#                                'priceEpsCurrentYear': 138.81558,
#                                'priceHint': 2,
#                                'priceToBook': 28.966951,
#                                'quoteSourceName': 'Nasdaq Real Time Price',
#                                'quoteType': 'EQUITY',
#                                'region': 'US',
#                                'regularMarketChange': -29.320007,
#                                'regularMarketChangePercent': -3.8604863,
#                                'regularMarketDayHigh': 742.0,
#                                'regularMarketDayLow': 718.6249,
#                                'regularMarketDayRange': '718.6249 - 742.0',
#                                'regularMarketOpen': 734.5577,
#                                'regularMarketPreviousClose': 759.49,
#                                'regularMarketPrice': 730.17,
#                                'regularMarketTime': 1632168003,
#                                'regularMarketVolume': 24385090,
#                                'sharesOutstanding': 1001769984,
#                                'shortName': 'Tesla, Inc.',
#                                'sourceInterval': 15,
#                                'symbol': 'TSLA',
#                                'tradeable': False,
#                                'trailingPE': 384.90775,
#                                'triggerable': True,
#                                'twoHundredDayAverage': 669.51166,
#                                'twoHundredDayAverageChange': 60.658325,
#                                'twoHundredDayAverageChangePercent': 0.09060085},
#                               {'ask': 4.4,
#                                'askSize': 18,
#                                'averageDailyVolume10Day': 46550,
#                                'averageDailyVolume3Month': 218658,
#                                'bid': 4.7,
#                                'bidSize': 10,
#                                'bookValue': 0.809,
#                                'currency': 'USD',
#                                'displayName': 'ZIVO Bioscience',
#                                'epsTrailingTwelveMonths': -1.732,
#                                'esgPopulated': False,
#                                'exchange': 'NCM',
#                                'exchangeDataDelayedBy': 0,
#                                'exchangeTimezoneName': 'America/New_York',
#                                'exchangeTimezoneShortName': 'EDT',
#                                'fiftyDayAverage': 3.2770588,
#                                'fiftyDayAverageChange': 1.382941,
#                                'fiftyDayAverageChangePercent': 0.42200676,
#                                'fiftyTwoWeekHigh': 7.9,
#                                'fiftyTwoWeekHighChange': -3.2400002,
#                                'fiftyTwoWeekHighChangePercent': -0.4101266,
#                                'fiftyTwoWeekLow': 0.08,
#                                'fiftyTwoWeekLowChange': 4.58,
#                                'fiftyTwoWeekLowChangePercent': 57.25,
#                                'fiftyTwoWeekRange': '0.08 - 7.9',
#                                'financialCurrency': 'USD',
#                                'firstTradeDateMilliseconds': 1071498600000,
#                                'fullExchangeName': 'NasdaqCM',
#                                'gmtOffSetMilliseconds': -14400000,
#                                'ipoExpectedDate': '2021-05-28',
#                                'language': 'en-US',
#                                'longName': 'ZIVO Bioscience, Inc.',
#                                'market': 'us_market',
#                                'marketCap': 42958956,
#                                'marketState': 'POST',
#                                'messageBoardId': 'finmb_7337423',
#                                'postMarketChange': -0.26999998,
#                                'postMarketChangePercent': -5.793991,
#                                'postMarketPrice': 4.39,
#                                'postMarketTime': 1632170774,
#                                'priceHint': 4,
#                                'priceToBook': 5.7601976,
#                                'quoteSourceName': 'Nasdaq Real Time Price',
#                                'quoteType': 'EQUITY',
#                                'region': 'US',
#                                'regularMarketChange': 1.8599999,
#                                'regularMarketChangePercent': 66.428566,
#                                'regularMarketDayHigh': 7.9,
#                                'regularMarketDayLow': 4.52,
#                                'regularMarketDayRange': '4.52 - 7.9',
#                                'regularMarketOpen': 5.98,
#                                'regularMarketPreviousClose': 2.8,
#                                'regularMarketPrice': 4.66,
#                                'regularMarketTime': 1632168002,
#                                'regularMarketVolume': 119759985,
#                                'sharesOutstanding': 9218660,
#                                'shortName': 'Zivo Bioscience, Inc.',
#                                'sourceInterval': 15,
#                                'symbol': 'ZIVO',
#                                'tradeable': False,
#                                'triggerable': True,
#                                'twoHundredDayAverage': 2.2150724,
#                                'twoHundredDayAverageChange': 2.4449275,
#                                'twoHundredDayAverageChangePercent': 1.1037686},
#                               {'averageDailyVolume10Day': 32767843516,
#                                'averageDailyVolume3Month': 32510185781,
#                                'circulatingSupply': 18821662,
#                                'coinImageUrl': 'https://s.yimg.com/uc/fin/img/reports-thumbnails/1.png',
#                                'currency': 'USD',
#                                'esgPopulated': False,
#                                'exchange': 'CCC',
#                                'exchangeDataDelayedBy': 0,
#                                'exchangeTimezoneName': 'Europe/London',
#                                'exchangeTimezoneShortName': 'BST',
#                                'fiftyDayAverage': 46515.508,
#                                'fiftyDayAverageChange': -3094.6055,
#                                'fiftyDayAverageChangePercent': -0.06652847,
#                                'fiftyTwoWeekHigh': 64863.098,
#                                'fiftyTwoWeekHighChange': -21442.195,
#                                'fiftyTwoWeekHighChangePercent': -0.33057618,
#                                'fiftyTwoWeekLow': 10185.774,
#                                'fiftyTwoWeekLowChange': 33235.13,
#                                'fiftyTwoWeekLowChangePercent': 3.2628965,
#                                'fiftyTwoWeekRange': '10185.774 - 64863.098',
#                                'firstTradeDateMilliseconds': 1410908400000,
#                                'fromCurrency': 'BTC',
#                                'fullExchangeName': 'CCC',
#                                'gmtOffSetMilliseconds': 3600000,
#                                'language': 'en-US',
#                                'lastMarket': 'CoinMarketCap',
#                                'market': 'ccc_market',
#                                'marketCap': 817253515264,
#                                'marketState': 'REGULAR',
#                                'messageBoardId': 'finmb_BTC_CCC',
#                                'priceHint': 2,
#                                'quoteSourceName': 'CoinMarketCap',
#                                'quoteType': 'CRYPTOCURRENCY',
#                                'region': 'US',
#                                'regularMarketChange': -4129.9062,
#                                'regularMarketChangePercent': -8.685248,
#                                'regularMarketDayHigh': 47269.414,
#                                'regularMarketDayLow': 42760.734,
#                                'regularMarketDayRange': '42760.734 - 47269.414',
#                                'regularMarketOpen': 47221.242,
#                                'regularMarketPreviousClose': 47221.242,
#                                'regularMarketPrice': 43420.902,
#                                'regularMarketTime': 1632170762,
#                                'regularMarketVolume': 42680832000,
#                                'shortName': 'Bitcoin USD',
#                                'sourceInterval': 15,
#                                'startDate': 1367103600,
#                                'symbol': 'BTC-USD',
#                                'toCurrency': 'USD=X',
#                                'tradeable': False,
#                                'triggerable': True,
#                                'twoHundredDayAverage': 45906.29,
#                                'twoHundredDayAverageChange': -2485.3867,
#                                'twoHundredDayAverageChangePercent': -0.05414044,
#                                'volume24Hr': 42680832000,
#                                'volumeAllCurrencies': 42680832000},
#                               {'ask': 34001.54,
#                                'askSize': 0,
#                                'averageDailyVolume10Day': 358158333,
#                                'averageDailyVolume3Month': 292187460,
#                                'bid': 33837.73,
#                                'bidSize': 0,
#                                'currency': 'USD',
#                                'esgPopulated': False,
#                                'exchange': 'DJI',
#                                'exchangeDataDelayedBy': 0,
#                                'exchangeTimezoneName': 'America/New_York',
#                                'exchangeTimezoneShortName': 'EDT',
#                                'fiftyDayAverage': 35138.49,
#                                'fiftyDayAverageChange': -1168.0195,
#                                'fiftyDayAverageChangePercent': -0.03324046,
#                                'fiftyTwoWeekHigh': 35631.19,
#                                'fiftyTwoWeekHighChange': -1660.7227,
#                                'fiftyTwoWeekHighChangePercent': -0.046608675,
#                                'fiftyTwoWeekLow': 26143.77,
#                                'fiftyTwoWeekLowChange': 7826.699,
#                                'fiftyTwoWeekLowChangePercent': 0.29937148,
#                                'fiftyTwoWeekRange': '26143.77 - 35631.19',
#                                'firstTradeDateMilliseconds': 694362600000,
#                                'fullExchangeName': 'DJI',
#                                'gmtOffSetMilliseconds': -14400000,
#                                'language': 'en-US',
#                                'market': 'us_market',
#                                'marketState': 'POST',
#                                'messageBoardId': 'finmb_INDEXDJI',
#                                'priceHint': 2,
#                                'quoteSourceName': 'Delayed Quote',
#                                'quoteType': 'INDEX',
#                                'region': 'US',
#                                'regularMarketChange': -614.41016,
#                                'regularMarketChangePercent': -1.7765284,
#                                'regularMarketDayHigh': 34459.72,
#                                'regularMarketDayLow': 33613.03,
#                                'regularMarketDayRange': '33613.03 - 34459.72',
#                                'regularMarketOpen': 34459.72,
#                                'regularMarketPreviousClose': 34584.88,
#                                'regularMarketPrice': 33970.47,
#                                'regularMarketTime': 1632169200,
#                                'regularMarketVolume': 435779440,
#                                'shortName': 'Dow Jones Industrial Average',
#                                'sourceInterval': 120,
#                                'symbol': '^DJI',
#                                'tradeable': False,
#                                'triggerable': True,
#                                'twoHundredDayAverage': 34242.938,
#                                'twoHundredDayAverageChange': -272.46875,
#                                'twoHundredDayAverageChangePercent': -0.007956932},
#                               {'ask': 0.0,
#                                'askSize': 0,
#                                'averageDailyVolume10Day': 0,
#                                'averageDailyVolume3Month': 0,
#                                'bid': 0.0,
#                                'bidSize': 0,
#                                'currency': 'USD',
#                                'esgPopulated': False,
#                                'exchange': 'WCB',
#                                'exchangeDataDelayedBy': 20,
#                                'exchangeTimezoneName': 'America/New_York',
#                                'exchangeTimezoneShortName': 'EDT',
#                                'fiftyDayAverage': 17.817648,
#                                'fiftyDayAverageChange': 7.892351,
#                                'fiftyDayAverageChangePercent': 0.44295135,
#                                'fiftyTwoWeekHigh': 41.16,
#                                'fiftyTwoWeekHighChange': -15.450001,
#                                'fiftyTwoWeekHighChangePercent': -0.37536445,
#                                'fiftyTwoWeekLow': 14.1,
#                                'fiftyTwoWeekLowChange': 11.609999,
#                                'fiftyTwoWeekLowChangePercent': 0.82340413,
#                                'fiftyTwoWeekRange': '14.1 - 41.16',
#                                'firstTradeDateMilliseconds': 631290600000,
#                                'fullExchangeName': 'Chicago Options',
#                                'gmtOffSetMilliseconds': -14400000,
#                                'language': 'en-US',
#                                'market': 'us_market',
#                                'marketState': 'POST',
#                                'messageBoardId': 'finmb_INDEXVIX',
#                                'priceHint': 2,
#                                'quoteType': 'INDEX',
#                                'region': 'US',
#                                'regularMarketChange': 4.8999996,
#                                'regularMarketChangePercent': 23.546371,
#                                'regularMarketDayHigh': 28.79,
#                                'regularMarketDayLow': 23.9,
#                                'regularMarketDayRange': '23.9 - 28.79',
#                                'regularMarketOpen': 24.25,
#                                'regularMarketPreviousClose': 20.81,
#                                'regularMarketPrice': 25.71,
#                                'regularMarketTime': 1632168890,
#                                'regularMarketVolume': 0,
#                                'shortName': 'CBOE Volatility Index',
#                                'sourceInterval': 15,
#                                'symbol': '^VIX',
#                                'tradeable': False,
#                                'triggerable': True,
#                                'twoHundredDayAverage': 18.38942,
#                                'twoHundredDayAverageChange': 7.3205795,
#                                'twoHundredDayAverageChangePercent': 0.3980865},
#                               {'ask': 0.0,
#                                'askSize': 0,
#                                'averageDailyVolume10Day': 4866,
#                                'averageDailyVolume3Month': 1138,
#                                'bid': 0.0,
#                                'bidSize': 0,
#                                'bookValue': 359.85,
#                                'currency': 'USD',
#                                'dividendDate': 1626998400,
#                                'epsTrailingTwelveMonths': 4.65,
#                                'esgPopulated': False,
#                                'exchange': 'PNK',
#                                'exchangeDataDelayedBy': 0,
#                                'exchangeTimezoneName': 'America/New_York',
#                                'exchangeTimezoneShortName': 'EDT',
#                                'fiftyDayAverage': 14.706617,
#                                'fiftyDayAverageChange': -6.2116175,
#                                'fiftyDayAverageChangePercent': -0.42236888,
#                                'fiftyTwoWeekHigh': 67.99,
#                                'fiftyTwoWeekHighChange': -59.495,
#                                'fiftyTwoWeekHighChangePercent': -0.8750552,
#                                'fiftyTwoWeekLow': 7.61,
#                                'fiftyTwoWeekLowChange': 0.88499975,
#                                'fiftyTwoWeekLowChangePercent': 0.11629432,
#                                'fiftyTwoWeekRange': '7.61 - 67.99',
#                                'financialCurrency': 'CNY',
#                                'firstTradeDateMilliseconds': 1470058200000,
#                                'fullExchangeName': 'Other OTC',
#                                'gmtOffSetMilliseconds': -14400000,
#                                'language': 'en-US',
#                                'longName': 'China Evergrande Group',
#                                'market': 'us_market',
#                                'marketCap': 4485750784,
#                                'marketState': 'POST',
#                                'messageBoardId': 'finmb_39388687',
#                                'priceHint': 2,
#                                'priceToBook': 0.023607058,
#                                'quoteSourceName': 'Delayed Quote',
#                                'quoteType': 'EQUITY',
#                                'region': 'US',
#                                'regularMarketChange': -2.4049997,
#                                'regularMarketChangePercent': -22.064219,
#                                'regularMarketDayHigh': 8.8,
#                                'regularMarketDayLow': 7.61,
#                                'regularMarketDayRange': '7.61 - 8.8',
#                                'regularMarketOpen': 7.62,
#                                'regularMarketPreviousClose': 10.9,
#                                'regularMarketPrice': 8.495,
#                                'regularMarketTime': 1632167941,
#                                'regularMarketVolume': 84064,
#                                'sharesOutstanding': 528046016,
#                                'shortName': 'CHINA EVERGRANDE GROUP',
#                                'sourceInterval': 15,
#                                'symbol': 'EGRNY',
#                                'tradeable': False,
#                                'trailingAnnualDividendRate': 0.152,
#                                'trailingAnnualDividendYield': 0.013944955,
#                                'trailingPE': 1.8268816,
#                                'triggerable': False,
#                                'twoHundredDayAverage': 33.98971,
#                                'twoHundredDayAverageChange': -25.494713,
#                                'twoHundredDayAverageChangePercent': -0.75007147},
#                               {'ask': 11.86,
#                                'askSize': 13,
#                                'averageDailyVolume10Day': 76200,
#                                'averageDailyVolume3Month': 65790,
#                                'bid': 11.89,
#                                'bidSize': 13,
#                                'bookValue': 1.192,
#                                'currency': 'USD',
#                                'displayName': 'Edesa Biotech',
#                                'dividendDate': 1560124800,
#                                'earningsTimestamp': 1628857800,
#                                'earningsTimestampEnd': 1639143000,
#                                'earningsTimestampStart': 1638797400,
#                                'epsCurrentYear': -1.17,
#                                'epsForward': -1.33,
#                                'epsTrailingTwelveMonths': -1.052,
#                                'esgPopulated': False,
#                                'exchange': 'NCM',
#                                'exchangeDataDelayedBy': 0,
#                                'exchangeTimezoneName': 'America/New_York',
#                                'exchangeTimezoneShortName': 'EDT',
#                                'fiftyDayAverage': 5.075,
#                                'fiftyDayAverageChange': 6.8450003,
#                                'fiftyDayAverageChangePercent': 1.3487686,
#                                'fiftyTwoWeekHigh': 12.0,
#                                'fiftyTwoWeekHighChange': -0.07999992,
#                                'fiftyTwoWeekHighChangePercent': -0.0066666603,
#                                'fiftyTwoWeekLow': 4.05,
#                                'fiftyTwoWeekLowChange': 7.87,
#                                'fiftyTwoWeekLowChangePercent': 1.9432098,
#                                'fiftyTwoWeekRange': '4.05 - 12.0',
#                                'financialCurrency': 'USD',
#                                'firstTradeDateMilliseconds': 1277127000000,
#                                'forwardPE': -8.962406,
#                                'fullExchangeName': 'NasdaqCM',
#                                'gmtOffSetMilliseconds': -14400000,
#                                'language': 'en-US',
#                                'longName': 'Edesa Biotech, Inc.',
#                                'market': 'us_market',
#                                'marketCap': 158006752,
#                                'marketState': 'POST',
#                                'messageBoardId': 'finmb_313039720',
#                                'postMarketChange': -1.21,
#                                'postMarketChangePercent': -10.151007,
#                                'postMarketPrice': 10.71,
#                                'postMarketTime': 1632170863,
#                                'priceEpsCurrentYear': -10.188035,
#                                'priceHint': 2,
#                                'priceToBook': 10.0,
#                                'quoteSourceName': 'Nasdaq Real Time Price',
#                                'quoteType': 'EQUITY',
#                                'region': 'US',
#                                'regularMarketChange': 6.04,
#                                'regularMarketChangePercent': 102.721085,
#                                'regularMarketDayHigh': 12.0,
#                                'regularMarketDayLow': 7.47,
#                                'regularMarketDayRange': '7.47 - 12.0',
#                                'regularMarketOpen': 9.45,
#                                'regularMarketPreviousClose': 5.88,
#                                'regularMarketPrice': 11.92,
#                                'regularMarketTime': 1632168003,
#                                'regularMarketVolume': 154286072,
#                                'sharesOutstanding': 13255600,
#                                'shortName': 'Edesa Biotech, Inc.',
#                                'sourceInterval': 15,
#                                'symbol': 'EDSA',
#                                'tradeable': False,
#                                'triggerable': True,
#                                'twoHundredDayAverage': 5.452971,
#                                'twoHundredDayAverageChange': 6.467029,
#                                'twoHundredDayAverageChangePercent': 1.1859643},
#                               {'ask': 211.27,
#                                'askSize': 8,
#                                'averageAnalystRating': '2.0 - Buy',
#                                'averageDailyVolume10Day': 22659483,
#                                'averageDailyVolume3Month': 32207087,
#                                'bid': 211.11,
#                                'bidSize': 14,
#                                'bookValue': 8.472,
#                                'currency': 'USD',
#                                'displayName': 'NVIDIA',
#                                'dividendDate': 1632355200,
#                                'earningsTimestamp': 1629303628,
#                                'earningsTimestampEnd': 1637582400,
#                                'earningsTimestampStart': 1637060340,
#                                'epsCurrentYear': 4.13,
#                                'epsForward': 4.64,
#                                'epsTrailingTwelveMonths': 2.792,
#                                'esgPopulated': False,
#                                'exchange': 'NMS',
#                                'exchangeDataDelayedBy': 0,
#                                'exchangeTimezoneName': 'America/New_York',
#                                'exchangeTimezoneShortName': 'EDT',
#                                'fiftyDayAverage': 212.90617,
#                                'fiftyDayAverageChange': -1.7761688,
#                                'fiftyDayAverageChangePercent': -0.008342495,
#                                'fiftyTwoWeekHigh': 230.43,
#                                'fiftyTwoWeekHighChange': -19.299988,
#                                'fiftyTwoWeekHighChangePercent': -0.0837564,
#                                'fiftyTwoWeekLow': 115.665,
#                                'fiftyTwoWeekLowChange': 95.465004,
#                                'fiftyTwoWeekLowChangePercent': 0.82535774,
#                                'fiftyTwoWeekRange': '115.665 - 230.43',
#                                'financialCurrency': 'USD',
#                                'firstTradeDateMilliseconds': 917015400000,
#                                'forwardPE': 45.50216,
#                                'fullExchangeName': 'NasdaqGS',
#                                'gmtOffSetMilliseconds': -14400000,
#                                'language': 'en-US',
#                                'longName': 'NVIDIA Corporation',
#                                'market': 'us_market',
#                                'marketCap': 526135984128,
#                                'marketState': 'POST',
#                                'messageBoardId': 'finmb_32307',
#                                'postMarketChange': -0.120010376,
#                                'postMarketChangePercent': -0.056841932,
#                                'postMarketPrice': 211.01,
#                                'postMarketTime': 1632170854,
#                                'priceEpsCurrentYear': 51.121067,
#                                'priceHint': 2,
#                                'priceToBook': 24.920916,
#                                'quoteSourceName': 'Nasdaq Real Time Price',
#                                'quoteType': 'EQUITY',
#                                'region': 'US',
#                                'regularMarketChange': -7.869995,
#                                'regularMarketChangePercent': -3.593605,
#                                'regularMarketDayHigh': 214.33,
#                                'regularMarketDayLow': 206.6253,
#                                'regularMarketDayRange': '206.6253 - 214.33',
#                                'regularMarketOpen': 211.46,
#                                'regularMarketPreviousClose': 219.0,
#                                'regularMarketPrice': 211.13,
#                                'regularMarketTime': 1632168003,
#                                'regularMarketVolume': 33886878,
#                                'sharesOutstanding': 2492000000,
#                                'shortName': 'NVIDIA Corporation',
#                                'sourceInterval': 15,
#                                'symbol': 'NVDA',
#                                'tradeable': False,
#                                'trailingAnnualDividendRate': 0.16,
#                                'trailingAnnualDividendYield': 0.0007305936,
#                                'trailingPE': 75.61963,
#                                'triggerable': True,
#                                'twoHundredDayAverage': 174.08282,
#                                'twoHundredDayAverageChange': 37.04718,
#                                'twoHundredDayAverageChangePercent': 0.21281353},
#                               {'ask': 28.97,
#                                'askSize': 11,
#                                'averageAnalystRating': '1.6 - Buy',
#                                'averageDailyVolume10Day': 1670900,
#                                'averageDailyVolume3Month': 1367692,
#                                'bid': 28.91,
#                                'bidSize': 9,
#                                'bookValue': 7.223,
#                                'currency': 'USD',
#                                'displayName': 'Atea Pharmaceuticals',
#                                'earningsTimestamp': 1628784305,
#                                'earningsTimestampEnd': 1628784305,
#                                'earningsTimestampStart': 1628784305,
#                                'epsCurrentYear': 0.58,
#                                'epsForward': 14.3,
#                                'epsTrailingTwelveMonths': 0.575,
#                                'esgPopulated': False,
#                                'exchange': 'NMS',
#                                'exchangeDataDelayedBy': 0,
#                                'exchangeTimezoneName': 'America/New_York',
#                                'exchangeTimezoneShortName': 'EDT',
#                                'fiftyDayAverage': 29.074411,
#                                'fiftyDayAverageChange': -0.13441086,
#                                'fiftyDayAverageChangePercent': -0.004622995,
#                                'fiftyTwoWeekHigh': 94.174,
#                                'fiftyTwoWeekHighChange': -65.234,
#                                'fiftyTwoWeekHighChangePercent': -0.6926965,
#                                'fiftyTwoWeekLow': 18.72,
#                                'fiftyTwoWeekLowChange': 10.220001,
#                                'fiftyTwoWeekLowChangePercent': 0.5459403,
#                                'fiftyTwoWeekRange': '18.72 - 94.174',
#                                'financialCurrency': 'USD',
#                                'firstTradeDateMilliseconds': 1604064600000,
#                                'forwardPE': 2.0237763,
#                                'fullExchangeName': 'NasdaqGS',
#                                'gmtOffSetMilliseconds': -14400000,
#                                'ipoExpectedDate': '2020-10-30',
#                                'language': 'en-US',
#                                'longName': 'Atea Pharmaceuticals, Inc.',
#                                'market': 'us_market',
#                                'marketCap': 2395563520,
#                                'marketState': 'POST',
#                                'messageBoardId': 'finmb_252824153',
#                                'postMarketChange': 0.0,
#                                'postMarketChangePercent': 0.0,
#                                'postMarketPrice': 28.94,
#                                'postMarketTime': 1632170591,
#                                'priceEpsCurrentYear': 49.896553,
#                                'priceHint': 2,
#                                'priceToBook': 4.0066457,
#                                'quoteSourceName': 'Nasdaq Real Time Price',
#                                'quoteType': 'EQUITY',
#                                'region': 'US',
#                                'regularMarketChange': 2.710001,
#                                'regularMarketChangePercent': 10.331685,
#                                'regularMarketDayHigh': 31.94,
#                                'regularMarketDayLow': 26.83,
#                                'regularMarketDayRange': '26.83 - 31.94',
#                                'regularMarketOpen': 27.0,
#                                'regularMarketPreviousClose': 26.23,
#                                'regularMarketPrice': 28.94,
#                                'regularMarketTime': 1632168003,
#                                'regularMarketVolume': 4662953,
#                                'sharesOutstanding': 82776896,
#                                'shortName': 'Atea Pharmaceuticals, Inc.',
#                                'sourceInterval': 15,
#                                'symbol': 'AVIR',
#                                'tradeable': False,
#                                'trailingPE': 50.330437,
#                                'triggerable': True,
#                                'twoHundredDayAverage': 34.159855,
#                                'twoHundredDayAverageChange': -5.2198544,
#                                'twoHundredDayAverageChangePercent': -0.15280668},
#                               {'ask': 3358.35,
#                                'askSize': 11,
#                                'averageAnalystRating': '1.7 - Buy',
#                                'averageDailyVolume10Day': 2842400,
#                                'averageDailyVolume3Month': 3256863,
#                                'bid': 3352.5,
#                                'bidSize': 8,
#                                'bookValue': 226.883,
#                                'currency': 'USD',
#                                'displayName': 'Amazon.com',
#                                'earningsTimestamp': 1627574460,
#                                'earningsTimestampEnd': 1635768000,
#                                'earningsTimestampStart': 1635332340,
#                                'epsCurrentYear': 53.38,
#                                'epsForward': 67.31,
#                                'epsTrailingTwelveMonths': 57.395,
#                                'esgPopulated': False,
#                                'exchange': 'NMS',
#                                'exchangeDataDelayedBy': 0,
#                                'exchangeTimezoneName': 'America/New_York',
#                                'exchangeTimezoneShortName': 'EDT',
#                                'fiftyDayAverage': 3371.3582,
#                                'fiftyDayAverageChange': -15.628174,
#                                'fiftyDayAverageChangePercent': -0.004635572,
#                                'fiftyTwoWeekHigh': 3773.08,
#                                'fiftyTwoWeekHighChange': -417.3501,
#                                'fiftyTwoWeekHighChangePercent': -0.11061257,
#                                'fiftyTwoWeekLow': 2871.0,
#                                'fiftyTwoWeekLowChange': 484.72998,
#                                'fiftyTwoWeekLowChangePercent': 0.16883664,
#                                'fiftyTwoWeekRange': '2871.0 - 3773.08',
#                                'financialCurrency': 'USD',
#                                'firstTradeDateMilliseconds': 863703000000,
#                                'forwardPE': 49.85485,
#                                'fullExchangeName': 'NasdaqGS',
#                                'gmtOffSetMilliseconds': -14400000,
#                                'language': 'en-US',
#                                'longName': 'Amazon.com, Inc.',
#                                'market': 'us_market',
#                                'marketCap': 1699479158784,
#                                'marketState': 'POST',
#                                'messageBoardId': 'finmb_18749',
#                                'postMarketChange': -0.050048828,
#                                'postMarketChangePercent': -0.0014914438,
#                                'postMarketPrice': 3355.68,
#                                'postMarketTime': 1632170862,
#                                'priceEpsCurrentYear': 62.86493,
#                                'priceHint': 2,
#                                'priceToBook': 14.790575,
#                                'quoteSourceName': 'Nasdaq Real Time Price',
#                                'quoteType': 'EQUITY',
#                                'region': 'US',
#                                'regularMarketChange': -106.79004,
#                                'regularMarketChangePercent': -3.084171,
#                                'regularMarketDayHigh': 3419.0,
#                                'regularMarketDayLow': 3305.01,
#                                'regularMarketDayRange': '3305.01 - 3419.0',
#                                'regularMarketOpen': 3396.0,
#                                'regularMarketPreviousClose': 3462.52,
#                                'regularMarketPrice': 3355.73,
#                                'regularMarketTime': 1632168002,
#                                'regularMarketVolume': 4491167,
#                                'sharesOutstanding': 506440992,
#                                'shortName': 'Amazon.com, Inc.',
#                                'sourceInterval': 15,
#                                'symbol': 'AMZN',
#                                'tradeable': False,
#                                'trailingPE': 58.46729,
#                                'triggerable': True,
#                                'twoHundredDayAverage': 3342.737,
#                                'twoHundredDayAverageChange': 12.99292,
#                                'twoHundredDayAverageChangePercent': 0.0038869106}]}}

# %%
## How many records did we get?
len(response2['quoteResponse']['result'])
# Out:
# 10

# %%
# Create a new DataFrame from all the results in the dictionary
response2_df = pd.DataFrame(response2['quoteResponse']['result'])
response2_df
# Out:
#   language region       quoteType         quoteSourceName  triggerable  \
# 0    en-US     US          EQUITY  Nasdaq Real Time Price         True
# 1    en-US     US          EQUITY  Nasdaq Real Time Price         True
# 2    en-US     US  CRYPTOCURRENCY           CoinMarketCap         True
# 3    en-US     US           INDEX           Delayed Quote         True
# 4    en-US     US           INDEX                     NaN         True
# 5    en-US     US          EQUITY           Delayed Quote        False
# 6    en-US     US          EQUITY  Nasdaq Real Time Price         True
# 7    en-US     US          EQUITY  Nasdaq Real Time Price         True
# 8    en-US     US          EQUITY  Nasdaq Real Time Price         True
# 9    en-US     US          EQUITY  Nasdaq Real Time Price         True
#
#   currency  fiftyTwoWeekLowChange  fiftyTwoWeekLowChangePercent  \
# 0      USD             378.870000                      1.078480
# 1      USD               4.580000                     57.250000
# 2      USD           33235.130000                      3.262897
# 3      USD            7826.699000                      0.299371
# 4      USD              11.609999                      0.823404
# 5      USD               0.885000                      0.116294
# 6      USD               7.870000                      1.943210
# 7      USD              95.465004                      0.825358
# 8      USD              10.220001                      0.545940
# 9      USD             484.729980                      0.168837
#
#        fiftyTwoWeekRange  fiftyTwoWeekHighChange  ...  \
# 0          351.3 - 900.4             -170.230040  ...
# 1             0.08 - 7.9               -3.240000  ...
# 2  10185.774 - 64863.098           -21442.195000  ...
# 3    26143.77 - 35631.19            -1660.722700  ...
# 4           14.1 - 41.16              -15.450001  ...
# 5           7.61 - 67.99              -59.495000  ...
# 6            4.05 - 12.0               -0.080000  ...
# 7       115.665 - 230.43              -19.299988  ...
# 8         18.72 - 94.174              -65.234000  ...
# 9       2871.0 - 3773.08             -417.350100  ...
#
#                                         coinImageUrl  circulatingSupply  \
# 0                                                NaN                NaN
# 1                                                NaN                NaN
# 2  https://s.yimg.com/uc/fin/img/reports-thumbnai...         18821662.0
# 3                                                NaN                NaN
# 4                                                NaN                NaN
# 5                                                NaN                NaN
# 6                                                NaN                NaN
# 7                                                NaN                NaN
# 8                                                NaN                NaN
# 9                                                NaN                NaN
#
#       lastMarket    volume24Hr  volumeAllCurrencies  fromCurrency  toCurrency  \
# 0            NaN           NaN                  NaN           NaN         NaN
# 1            NaN           NaN                  NaN           NaN         NaN
# 2  CoinMarketCap  4.268083e+10         4.268083e+10           BTC       USD=X
# 3            NaN           NaN                  NaN           NaN         NaN
# 4            NaN           NaN                  NaN           NaN         NaN
# 5            NaN           NaN                  NaN           NaN         NaN
# 6            NaN           NaN                  NaN           NaN         NaN
# 7            NaN           NaN                  NaN           NaN         NaN
# 8            NaN           NaN                  NaN           NaN         NaN
# 9            NaN           NaN                  NaN           NaN         NaN
#
#    dividendDate  trailingAnnualDividendRate  trailingAnnualDividendYield
# 0           NaN                         NaN                          NaN
# 1           NaN                         NaN                          NaN
# 2           NaN                         NaN                          NaN
# 3           NaN                         NaN                          NaN
# 4           NaN                         NaN                          NaN
# 5  1.626998e+09                       0.152                     0.013945
# 6  1.560125e+09                         NaN                          NaN
# 7  1.632355e+09                       0.160                     0.000731
# 8           NaN                         NaN                          NaN
# 9           NaN                         NaN                          NaN
#
# [10 rows x 84 columns]

# %% [markdown]
# # 3. STOCK HISTORY
#
# API domain: https://yfapi.net
# API path: /v8/finance/spark
# API variables:  querystring  {"symbols" : "string1,string2,string3,..."}
#                 interval  (1 minute to 1 month)
#                 range     (1 day to 1 month to 5 years)
#
# Pull data (extract) from yahoofinancials API (URL path is /v8/finance/spark) with "symbols" set to comma-separated list of up to 10 stock symbols at a time.  Specify data interval and range of desired time span.
#
# Use the query_string of 10 stock symbols.  Returns

# %%
## Query of /v8/finance/spark API

url = "https://yfapi.net/v8/finance/spark"
## Alternate url
# url = "https://rest.yahoofinanceapi.com/v8/finance/spark"

## Warning: no space between symbols
my_interval = "1d"
my_range = "1mo"
querystring = {"symbols" : query_string,
               "interval": my_interval,
               "range"   : my_range
              }

# Credentials to include
headers = {
    'x-api-key': API_KEY
    }

# %%
## Make API request (query string required for this API)
response3 = requests.request("GET", url, headers=headers, params=querystring).json()

# What does the response look like?  We will have to use indexing to get to the 'result' level
pprint.pprint(response3)
