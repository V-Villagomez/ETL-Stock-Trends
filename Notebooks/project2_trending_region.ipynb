# %% [markdown]
# # 1. TRENDING STOCK SYMBOLS
#
# API domain: https://yfapi.net
# API path: /v1/finance/trending/{region}
#
# Pull data (extract) from yahoofinancials API (URL path is /v1/finance/trending/{region}).
# It returns 20 stock symbols based on the region in the URL.
#
# Uses your basic subscription API key obtained from yahoofinancials web site.
# Current region: US

# %%
# Import required modules
import pandas as pd

# %%
##  Ensure you have your own config.py file in same folder so you can import your api key
##   and PostgreSQL database connection string variables
import requests
import pprint
from config import API_KEY
from config import username, password, host, port, database

region_selected = "US"
url = "https://yfapi.net/v1/finance/trending/" + region_selected
## Alternate url
# url = "https://rest.yahoofinanceapi.com/v1/finance/trending/" + region_selected

# Credentials to include
headers = {
    'x-api-key': API_KEY
    }

# %%
## Make API request (no query string required for this API)
response1 = requests.request("GET", url, headers=headers).json()

# What does the response look like?  We will have to use indexing to get to the 'result' level
pprint.pprint(response1)
# Out:
# {'finance': {'error': None,
#              'result': [{'count': 20,
#                          'jobTimestamp': 1632255052141,
#                          'quotes': [{'symbol': 'DIS'},
#                                     {'symbol': 'QS'},
#                                     {'symbol': 'UBER'},
#                                     {'symbol': 'LCID'},
#                                     {'symbol': 'RWLK'},
#                                     {'symbol': 'DKNG'},
#                                     {'symbol': 'UPST'},
#                                     {'symbol': 'NNVC'},
#                                     {'symbol': 'HLBZ'},
#                                     {'symbol': 'ABNB'},
#                                     {'symbol': 'GTEK'},
#                                     {'symbol': 'INDI'},
#                                     {'symbol': 'NURO'},
#                                     {'symbol': 'SAVA'},
#                                     {'symbol': 'CRVS'},
#                                     {'symbol': 'SEEL'},
#                                     {'symbol': 'SGOC'},
#                                     {'symbol': 'DISCB'},
#                                     {'symbol': 'BBIG'},
#                                     {'symbol': 'SPIR'}],
#                          'startInterval': 202109211900}]}}

# %% [markdown]
# # Optional: Check that 'error' was 'None'
# # Query pulled 20 stock symbols in US.

# %%
## How many responses did we get?  Single result with multiple columns
len(response1['finance']['result'])
# Out:
# 1

# %%
## Parse through the resulting dictionary tree to get at the 'results'.  Look at only the first
##  result in order to see what columns we received.
response1['finance']['result'][0]
# Out:
# {'count': 20,
#  'quotes': [{'symbol': 'DIS'},
#   {'symbol': 'QS'},
#   {'symbol': 'UBER'},
#   {'symbol': 'LCID'},
#   {'symbol': 'RWLK'},
#   {'symbol': 'DKNG'},
#   {'symbol': 'UPST'},
#   {'symbol': 'NNVC'},
#   {'symbol': 'HLBZ'},
#   {'symbol': 'ABNB'},
#   {'symbol': 'GTEK'},
#   {'symbol': 'INDI'},
#   {'symbol': 'NURO'},
#   {'symbol': 'SAVA'},
#   {'symbol': 'CRVS'},
#   {'symbol': 'SEEL'},
#   {'symbol': 'SGOC'},
#   {'symbol': 'DISCB'},
#   {'symbol': 'BBIG'},
#   {'symbol': 'SPIR'}],
#  'jobTimestamp': 1632255052141,
#  'startInterval': 202109211900}

# %%
# Create a new DataFrame from all the results in the dictionary
response1_df = pd.DataFrame(response1['finance']['result'])
response1_df.head()
# Out:
#    count                                             quotes   jobTimestamp  \
# 0     20  [{'symbol': 'DIS'}, {'symbol': 'QS'}, {'symbol...  1632255052141
#
#    startInterval
# 0   202109211900

# %%
# Extraction of the quotes, timestamp, startInterval
start_interval = response1_df['startInterval']
start_interval
# Out:
# 0    202109211900
# Name: startInterval, dtype: int64

# %%
# Loop through each stock symbol retrieved. Use later in retrieving quote and detail
## Using 'for' loop
# stock_list=[]
# for stock in response1_df['quotes'][0]:
#     #print(stock['symbol'])
#     stock_list.append(stock['symbol'])
## Using list comprehension notation
# stock_list = [stock['symbol'] for stock in response1_df['quotes'][0]]
stock_list = [stock['symbol'] for stock in response1_df['quotes'][0]]
stock_list
# Out:
# ['DIS',
#  'QS',
#  'UBER',
#  'LCID',
#  'RWLK',
#  'DKNG',
#  'UPST',
#  'NNVC',
#  'HLBZ',
#  'ABNB',
#  'GTEK',
#  'INDI',
#  'NURO',
#  'SAVA',
#  'CRVS',
#  'SEEL',
#  'SGOC',
#  'DISCB',
#  'BBIG',
#  'SPIR']

# %%
# The quote API query wants the list of symbols as a single comma separated string 
#  with no spaces.  Max is 10 per request.
query_string=''
for stock in stock_list:
    query_string += f"{stock},"
query_string = query_string.rstrip(',')
query_string
# Out:
# 'DIS,QS,UBER,LCID,RWLK,DKNG,UPST,NNVC,HLBZ,ABNB,GTEK,INDI,NURO,SAVA,CRVS,SEEL,SGOC,DISCB,BBIG,SPIR'

# %%
# For now, get the first 10 and run the quote API
query_string=''
for i in range(10):
    query_string += f"{response1_df['quotes'][0][i]['symbol']},"
query_string = query_string.rstrip(',')
query_string
# Out:
# 'DIS,QS,UBER,LCID,RWLK,DKNG,UPST,NNVC,HLBZ,ABNB'

# %% [markdown]
# # 2. REAL TIME QUOTE DATA
#
# API domain: https://yfapi.net
# API path: /v6/finance/quote
# API variables:  querystring  {"symbols" : "string1,string2,string3,..."}
#
# Pull data (extract) from yahoofinancials API (URL path is /v6/finance/quote) with "symbols" set to comma-separated list of up to 10 stock symbols at a time.
#
# Use the query_string of 10 stock symbols.

# %%
## Query of /v6/finance/quote API

url = "https://yfapi.net/v6/finance/quote"
## Alternate url
# url = "https://rest.yahoofinanceapi.com/v6/finance/quote"

## Warning: no space between symbols
querystring = {"symbols" : query_string}

# Credentials to include
headers = {
    'x-api-key': API_KEY
    }

# %%
## Make API request (query string required for this API)
response2 = requests.request("GET", url, headers=headers, params=querystring).json()

# What does the response look like?  We will have to use indexing to get to the 'result' level
pprint.pprint(response2)
# Out:
# {'quoteResponse': {'error': None,
#                    'result': [{'ask': 171.12,
#                                'askSize': 10,
#                                'averageAnalystRating': '1.9 - Buy',
#                                'averageDailyVolume10Day': 7116733,
#                                'averageDailyVolume3Month': 8272410,
#                                'bid': 171.03,
#                                'bidSize': 10,
#                                'bookValue': 48.243,
#                                'currency': 'USD',
#                                'dividendDate': 1579132800,
#                                'earningsTimestamp': 1628784300,
#                                'earningsTimestampEnd': 1636977600,
#                                'earningsTimestampStart': 1636541940,
#                                'epsCurrentYear': 2.45,
#                                'epsForward': 5.08,
#                                'epsTrailingTwelveMonths': 0.61,
#                                'esgPopulated': False,
#                                'exchange': 'NYQ',
#                                'exchangeDataDelayedBy': 0,
#                                'exchangeTimezoneName': 'America/New_York',
#                                'exchangeTimezoneShortName': 'EDT',
#                                'fiftyDayAverage': 179.44943,
#                                'fiftyDayAverageChange': -8.279434,
#                                'fiftyDayAverageChangePercent': -0.04613798,
#                                'fiftyTwoWeekHigh': 203.02,
#                                'fiftyTwoWeekHighChange': -31.850006,
#                                'fiftyTwoWeekHighChangePercent': -0.15688112,
#                                'fiftyTwoWeekLow': 117.23,
#                                'fiftyTwoWeekLowChange': 53.939995,
#                                'fiftyTwoWeekLowChangePercent': 0.46012107,
#                                'fiftyTwoWeekRange': '117.23 - 203.02',
#                                'financialCurrency': 'USD',
#                                'firstTradeDateMilliseconds': -252322200000,
#                                'forwardPE': 33.69488,
#                                'fullExchangeName': 'NYSE',
#                                'gmtOffSetMilliseconds': -14400000,
#                                'language': 'en-US',
#                                'longName': 'The Walt Disney Company',
#                                'market': 'us_market',
#                                'marketCap': 311038148608,
#                                'marketState': 'POST',
#                                'messageBoardId': 'finmb_191564',
#                                'postMarketChange': 0.05000305,
#                                'postMarketChangePercent': 0.029188637,
#                                'postMarketPrice': 171.36,
#                                'postMarketTime': 1632255629,
#                                'priceEpsCurrentYear': 69.8653,
#                                'priceHint': 2,
#                                'priceToBook': 3.5480795,
#                                'quoteSourceName': 'Nasdaq Real Time Price',
#                                'quoteType': 'EQUITY',
#                                'region': 'US',
#                                'regularMarketChange': -7.4400024,
#                                'regularMarketChangePercent': -4.1655016,
#                                'regularMarketDayHigh': 182.23,
#                                'regularMarketDayLow': 169.03,
#                                'regularMarketDayRange': '169.03 - 182.23',
#                                'regularMarketOpen': 180.32,
#                                'regularMarketPreviousClose': 178.61,
#                                'regularMarketPrice': 171.17,
#                                'regularMarketTime': 1632254591,
#                                'regularMarketVolume': 22596069,
#                                'sharesOutstanding': 1817129984,
#                                'shortName': 'Walt Disney Company (The)',
#                                'sourceInterval': 15,
#                                'symbol': 'DIS',
#                                'tradeable': False,
#                                'trailingAnnualDividendRate': 0.88,
#                                'trailingAnnualDividendYield': 0.004926936,
#                                'trailingPE': 280.60654,
#                                'triggerable': True,
#                                'twoHundredDayAverage': 181.05254,
#                                'twoHundredDayAverageChange': -9.882538,
#                                'twoHundredDayAverageChangePercent': -0.054583814},
#                               {'ask': 24.15,
#                                'askSize': 22,
#                                'averageAnalystRating': '2.7 - Hold',
#                                'averageDailyVolume10Day': 7176883,
#                                'averageDailyVolume3Month': 8412434,
#                                'bid': 24.14,
#                                'bidSize': 31,
#                                'bookValue': 3.634,
#                                'currency': 'USD',
#                                'displayName': 'QuantumScape',
#                                'earningsTimestamp': 1627416000,
#                                'earningsTimestampEnd': 1627416000,
#                                'earningsTimestampStart': 1627416000,
#                                'epsCurrentYear': -0.48,
#                                'epsForward': -0.46,
#                                'epsTrailingTwelveMonths': -5.363,
#                                'esgPopulated': False,
#                                'exchange': 'NYQ',
#                                'exchangeDataDelayedBy': 0,
#                                'exchangeTimezoneName': 'America/New_York',
#                                'exchangeTimezoneShortName': 'EDT',
#                                'fiftyDayAverage': 21.552856,
#                                'fiftyDayAverageChange': 2.5671444,
#                                'fiftyDayAverageChangePercent': 0.11910924,
#                                'fiftyTwoWeekHigh': 132.73,
#                                'fiftyTwoWeekHighChange': -108.60999,
#                                'fiftyTwoWeekHighChangePercent': -0.81827766,
#                                'fiftyTwoWeekLow': 11.25,
#                                'fiftyTwoWeekLowChange': 12.870001,
#                                'fiftyTwoWeekLowChangePercent': 1.144,
#                                'fiftyTwoWeekRange': '11.25 - 132.73',
#                                'financialCurrency': 'USD',
#                                'firstTradeDateMilliseconds': 1597671000000,
#                                'forwardPE': -52.434784,
#                                'fullExchangeName': 'NYSE',
#                                'gmtOffSetMilliseconds': -14400000,
#                                'language': 'en-US',
#                                'longName': 'QuantumScape Corporation',
#                                'market': 'us_market',
#                                'marketCap': 10001286144,
#                                'marketState': 'POST',
#                                'messageBoardId': 'finmb_204748122',
#                                'postMarketChange': -0.020000458,
#                                'postMarketChangePercent': -0.08292063,
#                                'postMarketPrice': 24.1,
#                                'postMarketTime': 1632255564,
#                                'priceEpsCurrentYear': -50.250004,
#                                'priceHint': 2,
#                                'priceToBook': 6.6373143,
#                                'quoteSourceName': 'Nasdaq Real Time Price',
#                                'quoteType': 'EQUITY',
#                                'region': 'US',
#                                'regularMarketChange': 3.33,
#                                'regularMarketChangePercent': 16.0173,
#                                'regularMarketDayHigh': 24.555,
#                                'regularMarketDayLow': 22.52,
#                                'regularMarketDayRange': '22.52 - 24.555',
#                                'regularMarketOpen': 23.18,
#                                'regularMarketPreviousClose': 20.79,
#                                'regularMarketPrice': 24.12,
#                                'regularMarketTime': 1632254402,
#                                'regularMarketVolume': 44582371,
#                                'sharesOutstanding': 305040000,
#                                'shortName': 'QuantumScape Corporation',
#                                'sourceInterval': 15,
#                                'symbol': 'QS',
#                                'tradeable': False,
#                                'triggerable': True,
#                                'twoHundredDayAverage': 31.126377,
#                                'twoHundredDayAverageChange': -7.0063763,
#                                'twoHundredDayAverageChangePercent': -0.2250945},
#                               {'ask': 44.38,
#                                'askSize': 10,
#                                'averageAnalystRating': '1.8 - Buy',
#                                'averageDailyVolume10Day': 31482316,
#                                'averageDailyVolume3Month': 22433745,
#                                'bid': 44.37,
#                                'bidSize': 8,
#                                'bookValue': 7.539,
#                                'currency': 'USD',
#                                'displayName': 'Uber',
#                                'earningsTimestamp': 1628093100,
#                                'earningsTimestampEnd': 1636372800,
#                                'earningsTimestampStart': 1635937140,
#                                'epsCurrentYear': -0.2,
#                                'epsForward': -0.54,
#                                'epsTrailingTwelveMonths': -0.568,
#                                'esgPopulated': False,
#                                'exchange': 'NYQ',
#                                'exchangeDataDelayedBy': 0,
#                                'exchangeTimezoneName': 'America/New_York',
#                                'exchangeTimezoneShortName': 'EDT',
#                                'fiftyDayAverage': 41.039715,
#                                'fiftyDayAverageChange': 3.3202858,
#                                'fiftyDayAverageChangePercent': 0.080904216,
#                                'fiftyTwoWeekHigh': 64.05,
#                                'fiftyTwoWeekHighChange': -19.690002,
#                                'fiftyTwoWeekHighChangePercent': -0.3074161,
#                                'fiftyTwoWeekLow': 32.89,
#                                'fiftyTwoWeekLowChange': 11.470001,
#                                'fiftyTwoWeekLowChangePercent': 0.34873825,
#                                'fiftyTwoWeekRange': '32.89 - 64.05',
#                                'financialCurrency': 'USD',
#                                'firstTradeDateMilliseconds': 1557495000000,
#                                'forwardPE': -82.14815,
#                                'fullExchangeName': 'NYSE',
#                                'gmtOffSetMilliseconds': -14400000,
#                                'language': 'en-US',
#                                'longName': 'Uber Technologies, Inc.',
#                                'market': 'us_market',
#                                'marketCap': 83589767168,
#                                'marketState': 'POST',
#                                'messageBoardId': 'finmb_144524848',
#                                'postMarketChange': -0.19000244,
#                                'postMarketChangePercent': -0.4283193,
#                                'postMarketPrice': 44.17,
#                                'postMarketTime': 1632255578,
#                                'priceEpsCurrentYear': -221.8,
#                                'priceHint': 2,
#                                'priceToBook': 5.8840694,
#                                'quoteSourceName': 'Nasdaq Real Time Price',
#                                'quoteType': 'EQUITY',
#                                'region': 'US',
#                                'regularMarketChange': 4.57,
#                                'regularMarketChangePercent': 11.4853,
#                                'regularMarketDayHigh': 45.0,
#                                'regularMarketDayLow': 42.18,
#                                'regularMarketDayRange': '42.18 - 45.0',
#                                'regularMarketOpen': 42.34,
#                                'regularMarketPreviousClose': 39.79,
#                                'regularMarketPrice': 44.36,
#                                'regularMarketTime': 1632254402,
#                                'regularMarketVolume': 103422504,
#                                'sharesOutstanding': 1884349952,
#                                'shortName': 'Uber Technologies, Inc.',
#                                'sourceInterval': 15,
#                                'symbol': 'UBER',
#                                'tradeable': False,
#                                'triggerable': True,
#                                'twoHundredDayAverage': 49.157246,
#                                'twoHundredDayAverageChange': -4.797245,
#                                'twoHundredDayAverageChangePercent': -0.09758978},
#                               {'ask': 26.78,
#                                'askSize': 9,
#                                'averageDailyVolume10Day': 48328166,
#                                'averageDailyVolume3Month': 17607373,
#                                'bid': 26.77,
#                                'bidSize': 32,
#                                'bookValue': -321.108,
#                                'currency': 'USD',
#                                'displayName': 'Lucid',
#                                'earningsTimestamp': 1620298740,
#                                'earningsTimestampEnd': 1620298740,
#                                'earningsTimestampStart': 1620298740,
#                                'epsTrailingTwelveMonths': -306.762,
#                                'esgPopulated': False,
#                                'exchange': 'NMS',
#                                'exchangeDataDelayedBy': 0,
#                                'exchangeTimezoneName': 'America/New_York',
#                                'exchangeTimezoneShortName': 'EDT',
#                                'fiftyDayAverage': 21.666,
#                                'fiftyDayAverageChange': 5.143999,
#                                'fiftyDayAverageChangePercent': 0.23742265,
#                                'fiftyTwoWeekHigh': 64.86,
#                                'fiftyTwoWeekHighChange': -38.050003,
#                                'fiftyTwoWeekHighChangePercent': -0.5866482,
#                                'fiftyTwoWeekLow': 9.6,
#                                'fiftyTwoWeekLowChange': 17.21,
#                                'fiftyTwoWeekLowChangePercent': 1.7927082,
#                                'fiftyTwoWeekRange': '9.6 - 64.86',
#                                'financialCurrency': 'USD',
#                                'firstTradeDateMilliseconds': 1600435800000,
#                                'fullExchangeName': 'NasdaqGS',
#                                'gmtOffSetMilliseconds': -14400000,
#                                'ipoExpectedDate': '2021-07-26',
#                                'language': 'en-US',
#                                'longName': 'Lucid Group, Inc.',
#                                'market': 'us_market',
#                                'marketCap': 43395203072,
#                                'marketState': 'POST',
#                                'messageBoardId': 'finmb_83747444',
#                                'postMarketChange': -0.15999985,
#                                'postMarketChangePercent': -0.5967917,
#                                'postMarketPrice': 26.65,
#                                'postMarketTime': 1632255623,
#                                'priceHint': 2,
#                                'priceToBook': -0.08349216,
#                                'quoteSourceName': 'Nasdaq Real Time Price',
#                                'quoteType': 'EQUITY',
#                                'region': 'US',
#                                'regularMarketChange': 2.7399998,
#                                'regularMarketChangePercent': 11.383464,
#                                'regularMarketDayHigh': 27.93,
#                                'regularMarketDayLow': 24.57,
#                                'regularMarketDayRange': '24.57 - 27.93',
#                                'regularMarketOpen': 24.78,
#                                'regularMarketPreviousClose': 24.07,
#                                'regularMarketPrice': 26.81,
#                                'regularMarketTime': 1632254402,
#                                'regularMarketVolume': 113572523,
#                                'sharesOutstanding': 1618620032,
#                                'shortName': 'Lucid Group, Inc.',
#                                'sourceInterval': 15,
#                                'symbol': 'LCID',
#                                'tradeable': False,
#                                'triggerable': True,
#                                'twoHundredDayAverage': 22.757318,
#                                'twoHundredDayAverageChange': 4.052681,
#                                'twoHundredDayAverageChangePercent': 0.17808254},
#                               {'ask': 2.59,
#                                'askSize': 18,
#                                'averageAnalystRating': '2.0 - Buy',
#                                'averageDailyVolume10Day': 345300,
#                                'averageDailyVolume3Month': 405090,
#                                'bid': 2.57,
#                                'bidSize': 18,
#                                'bookValue': 1.43,
#                                'currency': 'USD',
#                                'displayName': 'ReWalk Robotics',
#                                'dividendDate': 1554076800,
#                                'earningsTimestamp': 1628512200,
#                                'earningsTimestampEnd': 1636723800,
#                                'earningsTimestampStart': 1636378200,
#                                'epsCurrentYear': -0.28,
#                                'epsForward': -0.25,
#                                'epsTrailingTwelveMonths': -0.409,
#                                'esgPopulated': False,
#                                'exchange': 'NCM',
#                                'exchangeDataDelayedBy': 0,
#                                'exchangeTimezoneName': 'America/New_York',
#                                'exchangeTimezoneShortName': 'EDT',
#                                'fiftyDayAverage': 1.3668572,
#                                'fiftyDayAverageChange': 1.2231427,
#                                'fiftyDayAverageChangePercent': 0.89485776,
#                                'fiftyTwoWeekHigh': 6.0,
#                                'fiftyTwoWeekHighChange': -3.41,
#                                'fiftyTwoWeekHighChangePercent': -0.5683333,
#                                'fiftyTwoWeekLow': 1.0,
#                                'fiftyTwoWeekLowChange': 1.5899999,
#                                'fiftyTwoWeekLowChangePercent': 1.5899999,
#                                'fiftyTwoWeekRange': '1.0 - 6.0',
#                                'financialCurrency': 'USD',
#                                'firstTradeDateMilliseconds': 1410528600000,
#                                'forwardPE': -10.36,
#                                'fullExchangeName': 'NasdaqCM',
#                                'gmtOffSetMilliseconds': -14400000,
#                                'language': 'en-US',
#                                'longName': 'ReWalk Robotics Ltd.',
#                                'market': 'us_market',
#                                'marketCap': 120204488,
#                                'marketState': 'POST',
#                                'messageBoardId': 'finmb_268101180',
#                                'postMarketChange': -0.2099998,
#                                'postMarketChangePercent': -8.108101,
#                                'postMarketPrice': 2.38,
#                                'postMarketTime': 1632255628,
#                                'priceEpsCurrentYear': -9.25,
#                                'priceHint': 4,
#                                'priceToBook': 1.8111888,
#                                'quoteSourceName': 'Nasdaq Real Time Price',
#                                'quoteType': 'EQUITY',
#                                'region': 'US',
#                                'regularMarketChange': 1.29,
#                                'regularMarketChangePercent': 99.230774,
#                                'regularMarketDayHigh': 2.62,
#                                'regularMarketDayLow': 1.49,
#                                'regularMarketDayRange': '1.49 - 2.62',
#                                'regularMarketOpen': 1.5,
#                                'regularMarketPreviousClose': 1.3,
#                                'regularMarketPrice': 2.59,
#                                'regularMarketTime': 1632254402,
#                                'regularMarketVolume': 313363131,
#                                'sharesOutstanding': 46411000,
#                                'shortName': 'ReWalk Robotics Ltd.',
#                                'sourceInterval': 15,
#                                'symbol': 'RWLK',
#                                'tradeable': False,
#                                'triggerable': True,
#                                'twoHundredDayAverage': 1.8123769,
#                                'twoHundredDayAverageChange': 0.77762306,
#                                'twoHundredDayAverageChangePercent': 0.42906258},
#                               {'ask': 52.82,
#                                'askSize': 11,
#                                'averageAnalystRating': '2.0 - Buy',
#                                'averageDailyVolume10Day': 9162166,
#                                'averageDailyVolume3Month': 11001134,
#                                'bid': 52.8,
#                                'bidSize': 11,
#                                'bookValue': 5.479,
#                                'currency': 'USD',
#                                'displayName': 'DraftKings',
#                                'earningsTimestamp': 1628253000,
#                                'earningsTimestampEnd': 1636977600,
#                                'earningsTimestampStart': 1636628340,
#                                'epsCurrentYear': -2.85,
#                                'epsForward': -1.86,
#                                'epsTrailingTwelveMonths': -3.34,
#                                'esgPopulated': False,
#                                'exchange': 'NMS',
#                                'exchangeDataDelayedBy': 0,
#                                'exchangeTimezoneName': 'America/New_York',
#                                'exchangeTimezoneShortName': 'EDT',
#                                'fiftyDayAverage': 56.298,
#                                'fiftyDayAverageChange': -3.5279999,
#                                'fiftyDayAverageChangePercent': -0.06266652,
#                                'fiftyTwoWeekHigh': 74.38,
#                                'fiftyTwoWeekHighChange': -21.609997,
#                                'fiftyTwoWeekHighChangePercent': -0.29053506,
#                                'fiftyTwoWeekLow': 34.9,
#                                'fiftyTwoWeekLowChange': 17.869999,
#                                'fiftyTwoWeekLowChangePercent': 0.51203436,
#                                'fiftyTwoWeekRange': '34.9 - 74.38',
#                                'financialCurrency': 'USD',
#                                'firstTradeDateMilliseconds': 1564061400000,
#                                'forwardPE': -28.370968,
#                                'fullExchangeName': 'NasdaqGS',
#                                'gmtOffSetMilliseconds': -14400000,
#                                'language': 'en-US',
#                                'longName': 'DraftKings Inc.',
#                                'market': 'us_market',
#                                'marketCap': 21288579072,
#                                'marketState': 'POST',
#                                'messageBoardId': 'finmb_648976269',
#                                'postMarketChange': -0.11999893,
#                                'postMarketChangePercent': -0.2273999,
#                                'postMarketPrice': 52.65,
#                                'postMarketTime': 1632255598,
#                                'priceEpsCurrentYear': -18.51579,
#                                'priceHint': 2,
#                                'priceToBook': 9.631319,
#                                'quoteSourceName': 'Nasdaq Real Time Price',
#                                'quoteType': 'EQUITY',
#                                'region': 'US',
#                                'regularMarketChange': -4.2299995,
#                                'regularMarketChangePercent': -7.4210515,
#                                'regularMarketDayHigh': 58.02,
#                                'regularMarketDayLow': 52.33,
#                                'regularMarketDayRange': '52.33 - 58.02',
#                                'regularMarketOpen': 56.01,
#                                'regularMarketPreviousClose': 57.0,
#                                'regularMarketPrice': 52.77,
#                                'regularMarketTime': 1632254403,
#                                'regularMarketVolume': 39894442,
#                                'sharesOutstanding': 403422016,
#                                'shortName': 'DraftKings Inc.',
#                                'sourceInterval': 15,
#                                'symbol': 'DKNG',
#                                'tradeable': False,
#                                'triggerable': True,
#                                'twoHundredDayAverage': 54.841885,
#                                'twoHundredDayAverageChange': -2.0718842,
#                                'twoHundredDayAverageChangePercent': -0.03777923},
#                               {'ask': 321.2,
#                                'askSize': 13,
#                                'averageAnalystRating': '1.7 - Buy',
#                                'averageDailyVolume10Day': 5630333,
#                                'averageDailyVolume3Month': 5028376,
#                                'bid': 320.63,
#                                'bidSize': 14,
#                                'bookValue': 9.225,
#                                'currency': 'USD',
#                                'displayName': 'Upstart',
#                                'earningsTimestamp': 1628611500,
#                                'earningsTimestampEnd': 1628611500,
#                                'earningsTimestampStart': 1628611500,
#                                'epsCurrentYear': 1.33,
#                                'epsForward': 1.67,
#                                'epsTrailingTwelveMonths': 0.919,
#                                'esgPopulated': False,
#                                'exchange': 'NMS',
#                                'exchangeDataDelayedBy': 0,
#                                'exchangeTimezoneName': 'America/New_York',
#                                'exchangeTimezoneShortName': 'EDT',
#                                'fiftyDayAverage': 215.20314,
#                                'fiftyDayAverageChange': 105.56685,
#                                'fiftyDayAverageChangePercent': 0.49054512,
#                                'fiftyTwoWeekHigh': 329.46,
#                                'fiftyTwoWeekHighChange': -8.690002,
#                                'fiftyTwoWeekHighChangePercent': -0.026376503,
#                                'fiftyTwoWeekLow': 22.61,
#                                'fiftyTwoWeekLowChange': 298.15997,
#                                'fiftyTwoWeekLowChangePercent': 13.187084,
#                                'fiftyTwoWeekRange': '22.61 - 329.46',
#                                'financialCurrency': 'USD',
#                                'firstTradeDateMilliseconds': 1608129000000,
#                                'forwardPE': 192.07784,
#                                'fullExchangeName': 'NasdaqGS',
#                                'gmtOffSetMilliseconds': -14400000,
#                                'ipoExpectedDate': '2020-12-16',
#                                'language': 'en-US',
#                                'longName': 'Upstart Holdings, Inc.',
#                                'market': 'us_market',
#                                'marketCap': 24945448960,
#                                'marketState': 'POST',
#                                'messageBoardId': 'finmb_306975137',
#                                'postMarketChange': -2.769989,
#                                'postMarketChangePercent': -0.8635437,
#                                'postMarketPrice': 318.0,
#                                'postMarketTime': 1632255621,
#                                'priceEpsCurrentYear': 241.18044,
#                                'priceHint': 2,
#                                'priceToBook': 34.771812,
#                                'quoteSourceName': 'Nasdaq Real Time Price',
#                                'quoteType': 'EQUITY',
#                                'region': 'US',
#                                'regularMarketChange': 27.299988,
#                                'regularMarketChangePercent': 9.30248,
#                                'regularMarketDayHigh': 329.46,
#                                'regularMarketDayLow': 294.635,
#                                'regularMarketDayRange': '294.635 - 329.46',
#                                'regularMarketOpen': 297.64,
#                                'regularMarketPreviousClose': 293.47,
#                                'regularMarketPrice': 320.77,
#                                'regularMarketTime': 1632254403,
#                                'regularMarketVolume': 8775762,
#                                'sharesOutstanding': 77767400,
#                                'shortName': 'Upstart Holdings, Inc.',
#                                'sourceInterval': 15,
#                                'symbol': 'UPST',
#                                'tradeable': False,
#                                'trailingPE': 349.04242,
#                                'triggerable': True,
#                                'twoHundredDayAverage': 141.9351,
#                                'twoHundredDayAverageChange': 178.83488,
#                                'twoHundredDayAverageChangePercent': 1.2599764},
#                               {'ask': 6.27,
#                                'askSize': 18,
#                                'averageAnalystRating': '1.0 - Strong Buy',
#                                'averageDailyVolume10Day': 6099666,
#                                'averageDailyVolume3Month': 951520,
#                                'bid': 6.16,
#                                'bidSize': 9,
#                                'bookValue': 2.772,
#                                'currency': 'USD',
#                                'displayName': 'NanoViricides',
#                                'dividendDate': 1569283200,
#                                'earningsTimestamp': 1605560400,
#                                'earningsTimestampEnd': 1605560400,
#                                'earningsTimestampStart': 1605560400,
#                                'epsForward': -0.45,
#                                'epsTrailingTwelveMonths': -0.854,
#                                'esgPopulated': False,
#                                'exchange': 'ASE',
#                                'exchangeDataDelayedBy': 0,
#                                'exchangeTimezoneName': 'America/New_York',
#                                'exchangeTimezoneShortName': 'EDT',
#                                'fiftyDayAverage': 3.9085715,
#                                'fiftyDayAverageChange': 2.2814286,
#                                'fiftyDayAverageChangePercent': 0.5836988,
#                                'fiftyTwoWeekHigh': 8.71,
#                                'fiftyTwoWeekHighChange': -2.52,
#                                'fiftyTwoWeekHighChangePercent': -0.2893226,
#                                'fiftyTwoWeekLow': 2.85,
#                                'fiftyTwoWeekLowChange': 3.3400002,
#                                'fiftyTwoWeekLowChangePercent': 1.17193,
#                                'fiftyTwoWeekRange': '2.85 - 8.71',
#                                'financialCurrency': 'USD',
#                                'firstTradeDateMilliseconds': 1130333400000,
#                                'forwardPE': -13.755556,
#                                'fullExchangeName': 'NYSE American',
#                                'gmtOffSetMilliseconds': -14400000,
#                                'language': 'en-US',
#                                'longName': 'NanoViricides, Inc.',
#                                'market': 'us_market',
#                                'marketCap': 71215952,
#                                'marketState': 'POST',
#                                'messageBoardId': 'finmb_22594191',
#                                'postMarketChange': 0.6500001,
#                                'postMarketChangePercent': 10.500809,
#                                'postMarketPrice': 6.84,
#                                'postMarketTime': 1632255630,
#                                'priceHint': 2,
#                                'priceToBook': 2.2330446,
#                                'quoteSourceName': 'Nasdaq Real Time Price',
#                                'quoteType': 'EQUITY',
#                                'region': 'US',
#                                'regularMarketChange': 2.4,
#                                'regularMarketChangePercent': 63.3245,
#                                'regularMarketDayHigh': 7.86,
#                                'regularMarketDayLow': 4.7,
#                                'regularMarketDayRange': '4.7 - 7.86',
#                                'regularMarketOpen': 5.23,
#                                'regularMarketPreviousClose': 3.79,
#                                'regularMarketPrice': 6.19,
#                                'regularMarketTime': 1632254400,
#                                'regularMarketVolume': 98521934,
#                                'sharesOutstanding': 11505000,
#                                'shortName': 'NanoViricides, Inc.',
#                                'sourceInterval': 15,
#                                'symbol': 'NNVC',
#                                'tradeable': False,
#                                'triggerable': True,
#                                'twoHundredDayAverage': 4.1692753,
#                                'twoHundredDayAverageChange': 2.0207248,
#                                'twoHundredDayAverageChangePercent': 0.48467052},
#                               {'ask': 27.99,
#                                'askSize': 12,
#                                'averageAnalystRating': '1.0 - Strong Buy',
#                                'averageDailyVolume10Day': 11983450,
#                                'averageDailyVolume3Month': 1409351,
#                                'bid': 27.84,
#                                'bidSize': 9,
#                                'bookValue': -1.597,
#                                'currency': 'USD',
#                                'displayName': 'Helbiz',
#                                'epsCurrentYear': -0.77,
#                                'epsForward': -0.89,
#                                'epsTrailingTwelveMonths': -8.165,
#                                'esgPopulated': False,
#                                'exchange': 'NCM',
#                                'exchangeDataDelayedBy': 0,
#                                'exchangeTimezoneName': 'America/New_York',
#                                'exchangeTimezoneShortName': 'EDT',
#                                'fiftyDayAverage': 9.091429,
#                                'fiftyDayAverageChange': 19.13857,
#                                'fiftyDayAverageChangePercent': 2.1051226,
#                                'fiftyTwoWeekHigh': 41.88,
#                                'fiftyTwoWeekHighChange': -13.650002,
#                                'fiftyTwoWeekHighChangePercent': -0.32593125,
#                                'fiftyTwoWeekLow': 6.0,
#                                'fiftyTwoWeekLowChange': 22.23,
#                                'fiftyTwoWeekLowChangePercent': 3.705,
#                                'fiftyTwoWeekRange': '6.0 - 41.88',
#                                'financialCurrency': 'USD',
#                                'firstTradeDateMilliseconds': 1575901800000,
#                                'forwardPE': -31.7191,
#                                'fullExchangeName': 'NasdaqCM',
#                                'gmtOffSetMilliseconds': -14400000,
#                                'language': 'en-US',
#                                'longName': 'Helbiz, Inc.',
#                                'market': 'us_market',
#                                'marketCap': 1233145600,
#                                'marketState': 'POST',
#                                'messageBoardId': 'finmb_583302502',
#                                'postMarketChange': -1.5296001,
#                                'postMarketChangePercent': -5.41835,
#                                'postMarketPrice': 26.7004,
#                                'postMarketTime': 1632255615,
#                                'priceEpsCurrentYear': -36.66234,
#                                'priceHint': 2,
#                                'priceToBook': -17.676893,
#                                'quoteSourceName': 'Nasdaq Real Time Price',
#                                'quoteType': 'EQUITY',
#                                'region': 'US',
#                                'regularMarketChange': 13.87,
#                                'regularMarketChangePercent': 96.587746,
#                                'regularMarketDayHigh': 41.88,
#                                'regularMarketDayLow': 27.3,
#                                'regularMarketDayRange': '27.3 - 41.88',
#                                'regularMarketOpen': 34.25,
#                                'regularMarketPreviousClose': 14.36,
#                                'regularMarketPrice': 28.23,
#                                'regularMarketTime': 1632254402,
#                                'regularMarketVolume': 47982682,
#                                'sharesOutstanding': 29456200,
#                                'shortName': 'Helbiz, Inc.',
#                                'sourceInterval': 15,
#                                'symbol': 'HLBZ',
#                                'tradeable': False,
#                                'triggerable': True,
#                                'twoHundredDayAverage': 9.899565,
#                                'twoHundredDayAverageChange': 18.330435,
#                                'twoHundredDayAverageChangePercent': 1.8516405},
#                               {'ask': 169.29,
#                                'askSize': 32,
#                                'averageAnalystRating': '2.4 - Buy',
#                                'averageDailyVolume10Day': 8462433,
#                                'averageDailyVolume3Month': 6602892,
#                                'bid': 169.2,
#                                'bidSize': 8,
#                                'bookValue': 5.482,
#                                'currency': 'USD',
#                                'displayName': 'Airbnb',
#                                'earningsTimestamp': 1628798400,
#                                'earningsTimestampEnd': 1628798400,
#                                'earningsTimestampStart': 1628798400,
#                                'epsCurrentYear': -1.31,
#                                'epsForward': 0.44,
#                                'epsTrailingTwelveMonths': -10.764,
#                                'esgPopulated': False,
#                                'exchange': 'NMS',
#                                'exchangeDataDelayedBy': 0,
#                                'exchangeTimezoneName': 'America/New_York',
#                                'exchangeTimezoneShortName': 'EDT',
#                                'fiftyDayAverage': 154.81828,
#                                'fiftyDayAverageChange': 14.47171,
#                                'fiftyDayAverageChangePercent': 0.09347546,
#                                'fiftyTwoWeekHigh': 219.94,
#                                'fiftyTwoWeekHighChange': -50.65001,
#                                'fiftyTwoWeekHighChangePercent': -0.23029011,
#                                'fiftyTwoWeekLow': 121.5,
#                                'fiftyTwoWeekLowChange': 47.789993,
#                                'fiftyTwoWeekLowChangePercent': 0.3933333,
#                                'fiftyTwoWeekRange': '121.5 - 219.94',
#                                'financialCurrency': 'USD',
#                                'firstTradeDateMilliseconds': 1607610600000,
#                                'forwardPE': 384.75,
#                                'fullExchangeName': 'NasdaqGS',
#                                'gmtOffSetMilliseconds': -14400000,
#                                'ipoExpectedDate': '2020-12-10',
#                                'language': 'en-US',
#                                'longName': 'Airbnb, Inc.',
#                                'market': 'us_market',
#                                'marketCap': 106422968320,
#                                'marketState': 'POST',
#                                'messageBoardId': 'finmb_115705393',
#                                'postMarketChange': -0.7899933,
#                                'postMarketChangePercent': -0.4666509,
#                                'postMarketPrice': 168.5,
#                                'postMarketTime': 1632255553,
#                                'priceEpsCurrentYear': -129.229,
#                                'priceHint': 2,
#                                'priceToBook': 30.881065,
#                                'quoteSourceName': 'Nasdaq Real Time Price',
#                                'quoteType': 'EQUITY',
#                                'region': 'US',
#                                'regularMarketChange': 7.649994,
#                                'regularMarketChangePercent': 4.7327356,
#                                'regularMarketDayHigh': 170.01,
#                                'regularMarketDayLow': 163.0,
#                                'regularMarketDayRange': '163.0 - 170.01',
#                                'regularMarketOpen': 164.0,
#                                'regularMarketPreviousClose': 161.64,
#                                'regularMarketPrice': 169.29,
#                                'regularMarketTime': 1632254402,
#                                'regularMarketVolume': 8555306,
#                                'sharesOutstanding': 336553984,
#                                'shortName': 'Airbnb, Inc.',
#                                'sourceInterval': 15,
#                                'symbol': 'ABNB',
#                                'tradeable': False,
#                                'triggerable': True,
#                                'twoHundredDayAverage': 158.59044,
#                                'twoHundredDayAverageChange': 10.699554,
#                                'twoHundredDayAverageChangePercent': 0.06746658}]}}

# %%
## How many records did we get?
len(response2['quoteResponse']['result'])
# Out:
# 10

# %%
# Create a new DataFrame from all the results in the dictionary
response2_df = pd.DataFrame(response2['quoteResponse']['result'])
response2_df
# Out:
#   language region quoteType         quoteSourceName  triggerable currency  \
# 0    en-US     US    EQUITY  Nasdaq Real Time Price         True      USD
# 1    en-US     US    EQUITY  Nasdaq Real Time Price         True      USD
# 2    en-US     US    EQUITY  Nasdaq Real Time Price         True      USD
# 3    en-US     US    EQUITY  Nasdaq Real Time Price         True      USD
# 4    en-US     US    EQUITY  Nasdaq Real Time Price         True      USD
# 5    en-US     US    EQUITY  Nasdaq Real Time Price         True      USD
# 6    en-US     US    EQUITY  Nasdaq Real Time Price         True      USD
# 7    en-US     US    EQUITY  Nasdaq Real Time Price         True      USD
# 8    en-US     US    EQUITY  Nasdaq Real Time Price         True      USD
# 9    en-US     US    EQUITY  Nasdaq Real Time Price         True      USD
#
#                    shortName  firstTradeDateMilliseconds  \
# 0  Walt Disney Company (The)               -252322200000
# 1   QuantumScape Corporation               1597671000000
# 2    Uber Technologies, Inc.               1557495000000
# 3          Lucid Group, Inc.               1600435800000
# 4       ReWalk Robotics Ltd.               1410528600000
# 5            DraftKings Inc.               1564061400000
# 6     Upstart Holdings, Inc.               1608129000000
# 7        NanoViricides, Inc.               1130333400000
# 8               Helbiz, Inc.               1575901800000
# 9               Airbnb, Inc.               1607610600000
#
#    fiftyTwoWeekLowChangePercent  priceHint  ...  \
# 0                      0.460121          2  ...
# 1                      1.144000          2  ...
# 2                      0.348738          2  ...
# 3                      1.792708          2  ...
# 4                      1.590000          4  ...
# 5                      0.512034          2  ...
# 6                     13.187084          2  ...
# 7                      1.171930          2  ...
# 8                      3.705000          2  ...
# 9                      0.393333          2  ...
#
#    twoHundredDayAverageChangePercent     marketCap   forwardPE  priceToBook  \
# 0                          -0.054584  311038148608   33.694880     3.548080
# 1                          -0.225095   10001286144  -52.434784     6.637314
# 2                          -0.097590   83589767168  -82.148150     5.884069
# 3                           0.178083   43395203072         NaN    -0.083492
# 4                           0.429063     120204488  -10.360000     1.811189
# 5                          -0.037779   21288579072  -28.370968     9.631319
# 6                           1.259976   24945448960  192.077840    34.771812
# 7                           0.484671      71215952  -13.755556     2.233045
# 8                           1.851641    1233145600  -31.719100   -17.676893
# 9                           0.067467  106422968320  384.750000    30.881065
#
#    sourceInterval  exchangeDataDelayedBy  averageAnalystRating  symbol  \
# 0              15                      0             1.9 - Buy     DIS
# 1              15                      0            2.7 - Hold      QS
# 2              15                      0             1.8 - Buy    UBER
# 3              15                      0                   NaN    LCID
# 4              15                      0             2.0 - Buy    RWLK
# 5              15                      0             2.0 - Buy    DKNG
# 6              15                      0             1.7 - Buy    UPST
# 7              15                      0      1.0 - Strong Buy    NNVC
# 8              15                      0      1.0 - Strong Buy    HLBZ
# 9              15                      0             2.4 - Buy    ABNB
#
#        displayName ipoExpectedDate
# 0              NaN             NaN
# 1     QuantumScape             NaN
# 2             Uber             NaN
# 3            Lucid      2021-07-26
# 4  ReWalk Robotics             NaN
# 5       DraftKings             NaN
# 6          Upstart      2020-12-16
# 7    NanoViricides             NaN
# 8           Helbiz             NaN
# 9           Airbnb      2020-12-10
#
# [10 rows x 76 columns]

# %% [markdown]
# # 3. STOCK HISTORY
#
# API domain: https://yfapi.net
# API path: /v8/finance/spark
# API variables:  querystring  {"symbols" : "string1,string2,string3,..."}
#                 interval  (1 minute to 1 month)
#                 range     (1 day to 1 month to 5 years)
#
# Pull data (extract) from yahoofinancials API (URL path is /v8/finance/spark) with "symbols" set to comma-separated list of up to 10 stock symbols at a time.  Specify data interval and range of desired time span.
#
# Use the query_string of 10 stock symbols.  Returns

# %%
## Query of /v8/finance/spark API

url = "https://yfapi.net/v8/finance/spark"
## Alternate url
# url = "https://rest.yahoofinanceapi.com/v8/finance/spark"

## Warning: no space between symbols
my_interval = "1d"
my_range = "1mo"
querystring = {"symbols" : query_string,
               "interval": my_interval,
               "range"   : my_range
              }

# Credentials to include
headers = {
    'x-api-key': API_KEY
    }

# %%
## Make API request (query string required for this API)
response3 = requests.request("GET", url, headers=headers, params=querystring).json()

# What does the response look like?  We will have to use indexing to get to the 'result' level
pprint.pprint(response3)
# Out:
# {'ABNB': {'chartPreviousClose': 143.7,
#           'close': [146.79,
#                     161.42,
#                     160.35,
#                     152.73,
#                     154.18,
#                     156.02,
#                     154.99,
#                     156.59,
#                     157.2,
#                     158.0,
#                     165.0,
#                     163.93,
#                     166.0,
#                     165.2,
#                     160.32,
#                     163.3,
#                     166.37,
#                     168.15,
#                     166.59,
#                     161.64,
#                     169.29],
#           'dataGranularity': 300,
#           'end': None,
#           'previousClose': None,
#           'start': None,
#           'symbol': 'ABNB',
#           'timestamp': [1629725400,
#                         1629811800,
#                         1629898200,
#                         1629984600,
#                         1630071000,
#                         1630330200,
#                         1630416600,
#                         1630503000,
#                         1630589400,
#                         1630675800,
#                         1631021400,
#                         1631107800,
#                         1631194200,
#                         1631280600,
#                         1631539800,
#                         1631626200,
#                         1631712600,
#                         1631799000,
#                         1631885400,
#                         1632144600,
#                         1632254402]},
#  'DIS': {'chartPreviousClose': 175.12,
#          'close': [177.66,
#                    178.47,
#                    178.31,
#                    176.56,
#                    180.14,
#                    179.98,
#                    181.3,
#                    183.48,
#                    181.86,
#                    181.0,
#                    184.34,
#                    185.15,
#                    185.91,
#                    184.12,
#                    184.98,
#                    182.4,
#                    184.41,
#                    183.34,
#                    183.47,
#                    178.61,
#                    171.17],
#          'dataGranularity': 300,
#          'end': None,
#          'previousClose': None,
#          'start': None,
#          'symbol': 'DIS',
#          'timestamp': [1629725400,
#                        1629811800,
#                        1629898200,
#                        1629984600,
#                        1630071000,
#                        1630330200,
#                        1630416600,
#                        1630503000,
#                        1630589400,
#                        1630675800,
#                        1631021400,
#                        1631107800,
#                        1631194200,
#                        1631280600,
#                        1631539800,
#                        1631626200,
#                        1631712600,
#                        1631799000,
#                        1631885400,
#                        1632144600,
#                        1632254591]},
#  'DKNG': {'chartPreviousClose': 52.01,
#           'close': [53.32,
#                     56.47,
#                     60.11,
#                     57.86,
#                     60.01,
#                     59.25,
#                     59.29,
#                     60.21,
#                     61.07,
#                     61.02,
#                     63.58,
#                     63.39,
#                     63.67,
#                     62.46,
#                     60.46,
#                     59.05,
#                     59.84,
#                     59.97,
#                     60.42,
#                     57.0,
#                     52.77],
#           'dataGranularity': 300,
#           'end': None,
#           'previousClose': None,
#           'start': None,
#           'symbol': 'DKNG',
#           'timestamp': [1629725400,
#                         1629811800,
#                         1629898200,
#                         1629984600,
#                         1630071000,
#                         1630330200,
#                         1630416600,
#                         1630503000,
#                         1630589400,
#                         1630675800,
#                         1631021400,
#                         1631107800,
#                         1631194200,
#                         1631280600,
#                         1631539800,
#                         1631626200,
#                         1631712600,
#                         1631799000,
#                         1631885400,
#                         1632144600,
#                         1632254403]},
#  'HLBZ': {'chartPreviousClose': 7.99,
#           'close': [7.38,
#                     7.07,
#                     6.85,
#                     6.25,
#                     6.2,
#                     6.53,
#                     6.72,
#                     6.74,
#                     6.89,
#                     6.87,
#                     7.07,
#                     13.01,
#                     10.99,
#                     11.0,
#                     9.18,
#                     8.26,
#                     7.99,
#                     9.0,
#                     17.69,
#                     14.36,
#                     28.23],
#           'dataGranularity': 300,
#           'end': None,
#           'previousClose': None,
#           'start': None,
#           'symbol': 'HLBZ',
#           'timestamp': [1629725400,
#                         1629811800,
#                         1629898200,
#                         1629984600,
#                         1630071000,
#                         1630330200,
#                         1630416600,
#                         1630503000,
#                         1630589400,
#                         1630675800,
#                         1631021400,
#                         1631107800,
#                         1631194200,
#                         1631280600,
#                         1631539800,
#                         1631626200,
#                         1631712600,
#                         1631799000,
#                         1631885400,
#                         1632144600,
#                         1632254402]},
#  'LCID': {'chartPreviousClose': 21.67,
#           'close': [21.65,
#                     22.83,
#                     21.81,
#                     21.48,
#                     21.03,
#                     20.63,
#                     19.96,
#                     17.79,
#                     18.66,
#                     19.56,
#                     19.89,
#                     18.93,
#                     19.85,
#                     19.93,
#                     20.06,
#                     18.95,
#                     19.91,
#                     21.17,
#                     22.96,
#                     24.07,
#                     26.81],
#           'dataGranularity': 300,
#           'end': None,
#           'previousClose': None,
#           'start': None,
#           'symbol': 'LCID',
#           'timestamp': [1629725400,
#                         1629811800,
#                         1629898200,
#                         1629984600,
#                         1630071000,
#                         1630330200,
#                         1630416600,
#                         1630503000,
#                         1630589400,
#                         1630675800,
#                         1631021400,
#                         1631107800,
#                         1631194200,
#                         1631280600,
#                         1631539800,
#                         1631626200,
#                         1631712600,
#                         1631799000,
#                         1631885400,
#                         1632144600,
#                         1632254402]},
#  'NNVC': {'chartPreviousClose': 3.71,
#           'close': [3.8,
#                     3.82,
#                     3.92,
#                     3.91,
#                     3.85,
#                     3.85,
#                     3.87,
#                     3.92,
#                     4.02,
#                     4.02,
#                     3.94,
#                     3.96,
#                     4.1,
#                     3.94,
#                     4.07,
#                     4.83,
#                     4.25,
#                     4.08,
#                     4.02,
#                     3.79,
#                     6.19],
#           'dataGranularity': 300,
#           'end': None,
#           'previousClose': None,
#           'start': None,
#           'symbol': 'NNVC',
#           'timestamp': [1629725400,
#                         1629811800,
#                         1629898200,
#                         1629984600,
#                         1630071000,
#                         1630330200,
#                         1630416600,
#                         1630503000,
#                         1630589400,
#                         1630675800,
#                         1631021400,
#                         1631107800,
#                         1631194200,
#                         1631280600,
#                         1631539800,
#                         1631626200,
#                         1631712600,
#                         1631799000,
#                         1631885400,
#                         1632144600,
#                         1632254400]},
#  'QS': {'chartPreviousClose': 19.61,
#         'close': [20.59,
#                   21.3,
#                   21.25,
#                   21.27,
#                   21.48,
#                   21.4,
#                   22.0,
#                   22.2,
#                   22.46,
#                   22.45,
#                   22.18,
#                   20.74,
#                   21.39,
#                   21.08,
#                   21.15,
#                   20.86,
#                   20.61,
#                   21.34,
#                   21.8,
#                   20.79,
#                   24.12],
#         'dataGranularity': 300,
#         'end': None,
#         'previousClose': None,
#         'start': None,
#         'symbol': 'QS',
#         'timestamp': [1629725400,
#                       1629811800,
#                       1629898200,
#                       1629984600,
#                       1630071000,
#                       1630330200,
#                       1630416600,
#                       1630503000,
#                       1630589400,
#                       1630675800,
#                       1631021400,
#                       1631107800,
#                       1631194200,
#                       1631280600,
#                       1631539800,
#                       1631626200,
#                       1631712600,
#                       1631799000,
#                       1631885400,
#                       1632144600,
#                       1632254402]},
#  'RWLK': {'chartPreviousClose': 1.25,
#           'close': [1.29,
#                     1.41,
#                     1.35,
#                     1.38,
#                     1.41,
#                     1.4,
#                     1.37,
#                     1.39,
#                     1.34,
#                     1.33,
#                     1.29,
#                     1.29,
#                     1.25,
#                     1.27,
#                     1.25,
#                     1.35,
#                     1.3,
#                     2.59],
#           'dataGranularity': 300,
#           'end': None,
#           'previousClose': None,
#           'start': None,
#           'symbol': 'RWLK',
#           'timestamp': [1629725400,
#                         1629811800,
#                         1629984600,
#                         1630071000,
#                         1630330200,
#                         1630416600,
#                         1630503000,
#                         1630675800,
#                         1631021400,
#                         1631107800,
#                         1631194200,
#                         1631539800,
#                         1631626200,
#                         1631712600,
#                         1631799000,
#                         1631885400,
#                         1632144600,
#                         1632254402]},
#  'UBER': {'chartPreviousClose': 39.95,
#           'close': [41.0,
#                     40.17,
#                     41.55,
#                     40.62,
#                     40.69,
#                     39.59,
#                     39.14,
#                     40.62,
#                     41.4,
#                     40.32,
#                     40.95,
#                     40.07,
#                     40.35,
#                     39.89,
#                     40.07,
#                     39.01,
#                     38.48,
#                     39.52,
#                     39.75,
#                     39.79,
#                     44.36],
#           'dataGranularity': 300,
#           'end': None,
#           'previousClose': None,
#           'start': None,
#           'symbol': 'UBER',
#           'timestamp': [1629725400,
#                         1629811800,
#                         1629898200,
#                         1629984600,
#                         1630071000,
#                         1630330200,
#                         1630416600,
#                         1630503000,
#                         1630589400,
#                         1630675800,
#                         1631021400,
#                         1631107800,
#                         1631194200,
#                         1631280600,
#                         1631539800,
#                         1631626200,
#                         1631712600,
#                         1631799000,
#                         1631885400,
#                         1632144600,
#                         1632254402]},
#  'UPST': {'chartPreviousClose': 195.64,
#           'close': [202.96,
#                     219.45,
#                     214.14,
#                     216.75,
#                     223.18,
#                     215.64,
#                     229.12,
#                     226.81,
#                     239.8,
#                     247.29,
#                     262.7,
#                     274.33,
#                     289.6,
#                     270.46,
#                     278.0,
#                     269.04,
#                     279.09,
#                     293.26,
#                     303.32,
#                     293.47,
#                     320.77],
#           'dataGranularity': 300,
#           'end': None,
#           'previousClose': None,
#           'start': None,
#           'symbol': 'UPST',
#           'timestamp': [1629725400,
#                         1629811800,
#                         1629898200,
#                         1629984600,
#                         1630071000,
#                         1630330200,
#                         1630416600,
#                         1630503000,
#                         1630589400,
#                         1630675800,
#                         1631021400,
#                         1631107800,
#                         1631194200,
#                         1631280600,
#                         1631539800,
#                         1631626200,
#                         1631712600,
#                         1631799000,
#                         1631885400,
#                         1632144600,
#                         1632254403]}}

# %%
## How many records did we get?
len(response3)
# Out:
# 10

# %%
# Create a new DataFrame from all the results in the dictionary
response3_df = pd.DataFrame(response3)
response3_df
# Out:
#                                                                  DKNG  \
# dataGranularity                                                   300
# timestamp           [1629725400, 1629811800, 1629898200, 162998460...
# symbol                                                           DKNG
# previousClose                                                    None
# chartPreviousClose                                              52.01
# end                                                              None
# start                                                            None
# close               [53.32, 56.47, 60.11, 57.86, 60.01, 59.25, 59....
#
#                                                                  LCID  \
# dataGranularity                                                   300
# timestamp           [1629725400, 1629811800, 1629898200, 162998460...
# symbol                                                           LCID
# previousClose                                                    None
# chartPreviousClose                                              21.67
# end                                                              None
# start                                                            None
# close               [21.65, 22.83, 21.81, 21.48, 21.03, 20.63, 19....
#
#                                                                    QS  \
# dataGranularity                                                   300
# timestamp           [1629725400, 1629811800, 1629898200, 162998460...
# symbol                                                             QS
# previousClose                                                    None
# chartPreviousClose                                              19.61
# end                                                              None
# start                                                            None
# close               [20.59, 21.3, 21.25, 21.27, 21.48, 21.4, 22.0,...
#
#                                                                  RWLK  \
# dataGranularity                                                   300
# timestamp           [1629725400, 1629811800, 1629984600, 163007100...
# symbol                                                           RWLK
# previousClose                                                    None
# chartPreviousClose                                               1.25
# end                                                              None
# start                                                            None
# close               [1.29, 1.41, 1.35, 1.38, 1.41, 1.4, 1.37, 1.39...
#
#                                                                  NNVC  \
# dataGranularity                                                   300
# timestamp           [1629725400, 1629811800, 1629898200, 162998460...
# symbol                                                           NNVC
# previousClose                                                    None
# chartPreviousClose                                               3.71
# end                                                              None
# start                                                            None
# close               [3.8, 3.82, 3.92, 3.91, 3.85, 3.85, 3.87, 3.92...
#
#                                                                  UPST  \
# dataGranularity                                                   300
# timestamp           [1629725400, 1629811800, 1629898200, 162998460...
# symbol                                                           UPST
# previousClose                                                    None
# chartPreviousClose                                             195.64
# end                                                              None
# start                                                            None
# close               [202.96, 219.45, 214.14, 216.75, 223.18, 215.6...
#
#                                                                  ABNB  \
# dataGranularity                                                   300
# timestamp           [1629725400, 1629811800, 1629898200, 162998460...
# symbol                                                           ABNB
# previousClose                                                    None
# chartPreviousClose                                              143.7
# end                                                              None
# start                                                            None
# close               [146.79, 161.42, 160.35, 152.73, 154.18, 156.0...
#
#                                                                  UBER  \
# dataGranularity                                                   300
# timestamp           [1629725400, 1629811800, 1629898200, 162998460...
# symbol                                                           UBER
# previousClose                                                    None
# chartPreviousClose                                              39.95
# end                                                              None
# start                                                            None
# close               [41.0, 40.17, 41.55, 40.62, 40.69, 39.59, 39.1...
#
#                                                                  HLBZ  \
# dataGranularity                                                   300
# timestamp           [1629725400, 1629811800, 1629898200, 162998460...
# symbol                                                           HLBZ
# previousClose                                                    None
# chartPreviousClose                                               7.99
# end                                                              None
# start                                                            None
# close               [7.38, 7.07, 6.85, 6.25, 6.2, 6.53, 6.72, 6.74...
#
#                                                                   DIS
# dataGranularity                                                   300
# timestamp           [1629725400, 1629811800, 1629898200, 162998460...
# symbol                                                            DIS
# previousClose                                                    None
# chartPreviousClose                                             175.12
# end                                                              None
# start                                                            None
# close               [177.66, 178.47, 178.31, 176.56, 180.14, 179.9...

# %%
# Or try to turn the dictionary of dictionaries into a list of dictionaries before
# Feeding it into a dataframe.  Dataframes are best as list of dictionaries.
# THIS STEP WOULD BE CONSIDERED A TRANSFORMATION

list3 = []
for value in response3:
    # print(response3[value])
    list3.append(response3[value])
## Alternate syntax with list comprehension
# list3 = [response3[value] for value in response3]
list3[0]
# Out:
# {'dataGranularity': 300,
#  'timestamp': [1629725400,
#   1629811800,
#   1629898200,
#   1629984600,
#   1630071000,
#   1630330200,
#   1630416600,
#   1630503000,
#   1630589400,
#   1630675800,
#   1631021400,
#   1631107800,
#   1631194200,
#   1631280600,
#   1631539800,
#   1631626200,
#   1631712600,
#   1631799000,
#   1631885400,
#   1632144600,
#   1632254403],
#  'symbol': 'DKNG',
#  'previousClose': None,
#  'chartPreviousClose': 52.01,
#  'end': None,
#  'start': None,
#  'close': [53.32,
#   56.47,
#   60.11,
#   57.86,
#   60.01,
#   59.25,
#   59.29,
#   60.21,
#   61.07,
#   61.02,
#   63.58,
#   63.39,
#   63.67,
#   62.46,
#   60.46,
#   59.05,
#   59.84,
#   59.97,
#   60.42,
#   57.0,
#   52.77]}

# %%
list3_df = pd.DataFrame(list3)
list3_df
# Out:
#    dataGranularity                                          timestamp symbol  \
# 0              300  [1629725400, 1629811800, 1629898200, 162998460...   DKNG
# 1              300  [1629725400, 1629811800, 1629898200, 162998460...   LCID
# 2              300  [1629725400, 1629811800, 1629898200, 162998460...     QS
# 3              300  [1629725400, 1629811800, 1629984600, 163007100...   RWLK
# 4              300  [1629725400, 1629811800, 1629898200, 162998460...   NNVC
# 5              300  [1629725400, 1629811800, 1629898200, 162998460...   UPST
# 6              300  [1629725400, 1629811800, 1629898200, 162998460...   ABNB
# 7              300  [1629725400, 1629811800, 1629898200, 162998460...   UBER
# 8              300  [1629725400, 1629811800, 1629898200, 162998460...   HLBZ
# 9              300  [1629725400, 1629811800, 1629898200, 162998460...    DIS
#
#   previousClose  chartPreviousClose   end start  \
# 0          None               52.01  None  None
# 1          None               21.67  None  None
# 2          None               19.61  None  None
# 3          None                1.25  None  None
# 4          None                3.71  None  None
# 5          None              195.64  None  None
# 6          None              143.70  None  None
# 7          None               39.95  None  None
# 8          None                7.99  None  None
# 9          None              175.12  None  None
#
#                                                close
# 0  [53.32, 56.47, 60.11, 57.86, 60.01, 59.25, 59....
# 1  [21.65, 22.83, 21.81, 21.48, 21.03, 20.63, 19....
# 2  [20.59, 21.3, 21.25, 21.27, 21.48, 21.4, 22.0,...
# 3  [1.29, 1.41, 1.35, 1.38, 1.41, 1.4, 1.37, 1.39...
# 4  [3.8, 3.82, 3.92, 3.91, 3.85, 3.85, 3.87, 3.92...
# 5  [202.96, 219.45, 214.14, 216.75, 223.18, 215.6...
# 6  [146.79, 161.42, 160.35, 152.73, 154.18, 156.0...
# 7  [41.0, 40.17, 41.55, 40.62, 40.69, 39.59, 39.1...
# 8  [7.38, 7.07, 6.85, 6.25, 6.2, 6.53, 6.72, 6.74...
# 9  [177.66, 178.47, 178.31, 176.56, 180.14, 179.9...

# %% [markdown]
# # 4. Steps beyond
#
# We could save the raw outputs into 3 database tables.
#
# Transformations (either in the database or here in Jupyter Notebook):
# From above, we would probably want another table with the stock symbol, timestamp, and closing price.  Do we need 'time of capture' column?
# For time stamp, we would likely need the Python code that can transform this Unix time stamp into a MM-DD-YYYY format when inputing into PostGres table.  Or we can ingest this field as-is and then in database perform the calculation.
#
# Transforming: renaming columns, taking fewer columns into new dataframe before loading, calculating new needed columns, dropping duplicates
#
# Load (in the database):
# Decide for each raw table above which columns will be needed for the final set of tables.  Make those tables, calculations, etc, and produce the final set of tables.  Set up connection string and method for how to transfer dataframe into database tables.

# %%
# TRANSFORM: Need to make each timestamp its own row in the table first, not clumped
# Transforming the timestamp from 'seconds since epoch' to 'mm/dd/yyyy'

# %%
# Example: Access the first record's timestamps
list3_df['timestamp'][0]
# Out:
# [1629725400,
#  1629811800,
#  1629898200,
#  1629984600,
#  1630071000,
#  1630330200,
#  1630416600,
#  1630503000,
#  1630589400,
#  1630675800,
#  1631021400,
#  1631107800,
#  1631194200,
#  1631280600,
#  1631539800,
#  1631626200,
#  1631712600,
#  1631799000,
#  1631885400,
#  1632144600,
#  1632254403]

# %%
timestamp1_record1 = list3_df['timestamp'][0][0]
timestamp1_record1
# Out:
# 1629725400

# %%
# Convert to regular date time
pd.to_datetime(timestamp1_record1, unit='s')
# Out:
# Timestamp('2021-08-23 13:30:00')

# %% [markdown]
# # 5. Connect to database
# Use the values pulled in from config.py to construct the database connection string.  Connect to the database.

# %%
from sqlalchemy import create_engine

# Define the engine string to be used for connecting to your database using the 
#  environment variables found in config.py

database_url = f'postgresql://{username}:{password}@{host}:{port}/{database}'
database_url = f"postgresql://{username}:{password}@{host}:5432/{database}"
### Alternate URLs
# database_url = os.environ.get('DATABASE_URL', 'postgresql://localhost:5432/EmployeeSQL')
# connection_string = f'${username}:${password}@${host}:${port}/${database}'
# engine = create_engine(f'postgresql://{connection_string}')
engine = create_engine(database_url)
# connection = engine.connect()

# %%
# Example of how to work with subset of data into a new dataframe
# new_customer_data_df = customer_data_df[['id', 'first_name', 'last_name']].copy()
# new_customer_data_df.head()

# Write dataframe to database, decide whether index is true or false, depending on
#   whether the index should be a column or not (possible primary key column)
# transformed_data_df.to_sql(name='customer_name', con=engine, if_exists='append', index=False)
# premise_transformed_df.to_sql(name='premise', con=engine, if_exists='append', index=True)

# Verify data presence by querying database
pd.read_sql_query('select * from departments', con=engine).head()
# Out:
#   dept_no        dept_name
# 0    d001        Marketing
# 1    d002          Finance
# 2    d003  Human Resources
# 3    d004       Production
# 4    d005      Development
