# %% [markdown]
# # 1. TRENDING STOCK SYMBOLS
#
# API domain: https://yfapi.net
# API path: /v1/finance/trending/{region}
#
# Pull data (extract) from yahoofinancials API (URL path is /v1/finance/trending/{region}).
# It returns 20 stock symbols based on the region in the URL.
#
# Uses your basic subscription API key obtained from yahoofinancials web site.
# Current region: US

# %%
# Import required modules
import pandas as pd

# %%
##  Ensure you have your own config.py file in same folder so you can import your api key
import requests
import pprint
from config import API_KEY

region_selected = "US"
url = "https://yfapi.net/v1/finance/trending/" + region_selected
## Alternate url
# url = "https://rest.yahoofinanceapi.com/v1/finance/trending/" + region_selected

# Credentials to include
headers = {
    'x-api-key': API_KEY
    }

# %%
## Make API request (no query string required for this API)
response1 = requests.request("GET", url, headers=headers).json()

# What does the response look like?  We will have to use indexing to get to the 'result' level
pprint.pprint(response1)
# Out:
# {'finance': {'error': None,
#              'result': [{'count': 20,
#                          'jobTimestamp': 1632172086193,
#                          'quotes': [{'symbol': '^DJI'},
#                                     {'symbol': 'BABA'},
#                                     {'symbol': 'ZIVO'},
#                                     {'symbol': 'BTC-USD'},
#                                     {'symbol': '^GSPC'},
#                                     {'symbol': 'EDSA'},
#                                     {'symbol': '^IXIC'},
#                                     {'symbol': 'AMZN'},
#                                     {'symbol': '^VIX'},
#                                     {'symbol': 'DISCB'},
#                                     {'symbol': 'LEN'},
#                                     {'symbol': '3333.HK'},
#                                     {'symbol': 'EGRNY'},
#                                     {'symbol': 'SPY'},
#                                     {'symbol': 'NVDA'},
#                                     {'symbol': 'NIO'},
#                                     {'symbol': 'NWAU'},
#                                     {'symbol': 'ARQQ'},
#                                     {'symbol': 'AAL'},
#                                     {'symbol': 'TQQQ'}],
#                          'startInterval': 202109202000}]}}

# %% [markdown]
# # Optional: Check that 'error' was 'None'
# # Query pulled 20 stock symbols in US.

# %%
## How many responses did we get?  Single result with multiple columns
len(response1['finance']['result'])
# Out:
# 1

# %%
## Parse through the resulting dictionary tree to get at the 'results'.  Look at only the first
##  result in order to see what columns we received.
response1['finance']['result'][0]
# Out:
# {'count': 20,
#  'quotes': [{'symbol': '^DJI'},
#   {'symbol': 'BABA'},
#   {'symbol': 'ZIVO'},
#   {'symbol': 'BTC-USD'},
#   {'symbol': '^GSPC'},
#   {'symbol': 'EDSA'},
#   {'symbol': '^IXIC'},
#   {'symbol': 'AMZN'},
#   {'symbol': '^VIX'},
#   {'symbol': 'DISCB'},
#   {'symbol': 'LEN'},
#   {'symbol': '3333.HK'},
#   {'symbol': 'EGRNY'},
#   {'symbol': 'SPY'},
#   {'symbol': 'NVDA'},
#   {'symbol': 'NIO'},
#   {'symbol': 'NWAU'},
#   {'symbol': 'ARQQ'},
#   {'symbol': 'AAL'},
#   {'symbol': 'TQQQ'}],
#  'jobTimestamp': 1632172086193,
#  'startInterval': 202109202000}

# %%
# Create a new DataFrame from all the results in the dictionary
response1_df = pd.DataFrame(response1['finance']['result'])
response1_df.head()
# Out:
#    count                                             quotes   jobTimestamp  \
# 0     20  [{'symbol': '^DJI'}, {'symbol': 'BABA'}, {'sym...  1632172086193
#
#    startInterval
# 0   202109202000

# %%
# Extraction of the quotes, timestamp, startInterval
start_interval = response1_df['startInterval']
start_interval
# Out:
# 0    202109202000
# Name: startInterval, dtype: int64

# %%
# Loop through each stock symbol retrieved. Use later in retrieving quote and detail
## Using 'for' loop
# stock_list=[]
# for stock in response1_df['quotes'][0]:
#     #print(stock['symbol'])
#     stock_list.append(stock['symbol'])
## Using list comprehension notation
# stock_list = [stock['symbol'] for stock in response1_df['quotes'][0]]
stock_list = [stock['symbol'] for stock in response1_df['quotes'][0]]
stock_list
# Out:
# ['^DJI',
#  'BABA',
#  'ZIVO',
#  'BTC-USD',
#  '^GSPC',
#  'EDSA',
#  '^IXIC',
#  'AMZN',
#  '^VIX',
#  'DISCB',
#  'LEN',
#  '3333.HK',
#  'EGRNY',
#  'SPY',
#  'NVDA',
#  'NIO',
#  'NWAU',
#  'ARQQ',
#  'AAL',
#  'TQQQ']

# %%
# The quote API query wants the list of symbols as a single comma separated string 
#  with no spaces.  Max is 10 per request.
query_string=''
for stock in stock_list:
    query_string += f"{stock},"
query_string = query_string.rstrip(',')
query_string
# Out:
# '^DJI,BABA,ZIVO,BTC-USD,^GSPC,EDSA,^IXIC,AMZN,^VIX,DISCB,LEN,3333.HK,EGRNY,SPY,NVDA,NIO,NWAU,ARQQ,AAL,TQQQ'

# %%
# For now, get the first 10 and run the quote API
query_string=''
for i in range(10):
    query_string += f"{response1_df['quotes'][0][i]['symbol']},"
query_string = query_string.rstrip(',')
query_string
# Out:
# '^DJI,BABA,ZIVO,BTC-USD,^GSPC,EDSA,^IXIC,AMZN,^VIX,DISCB'

# %% [markdown]
# # 2. REAL TIME QUOTE DATA
#
# API domain: https://yfapi.net
# API path: /v6/finance/quote
# API variables:  querystring  {"symbols" : "string1,string2,string3,..."}
#
# Pull data (extract) from yahoofinancials API (URL path is /v6/finance/quote) with "symbols" set to comma-separated list of up to 10 stock symbols at a time.
#
# Use the query_string of 10 stock symbols.

# %%
## Query of /v6/finance/quote API

url = "https://yfapi.net/v6/finance/quote"
## Alternate url
# url = "https://rest.yahoofinanceapi.com/v6/finance/quote"

## Warning: no space between symbols
querystring = {"symbols" : query_string}

# Credentials to include
headers = {
    'x-api-key': API_KEY
    }

# %%
## Make API request (query string required for this API)
response2 = requests.request("GET", url, headers=headers, params=querystring).json()

# What does the response look like?  We will have to use indexing to get to the 'result' level
pprint.pprint(response2)
# Out:
# {'quoteResponse': {'error': None,
#                    'result': [{'ask': 34053.03,
#                                'askSize': 0,
#                                'averageDailyVolume10Day': 358158333,
#                                'averageDailyVolume3Month': 292187460,
#                                'bid': 33866.97,
#                                'bidSize': 0,
#                                'currency': 'USD',
#                                'esgPopulated': False,
#                                'exchange': 'DJI',
#                                'exchangeDataDelayedBy': 0,
#                                'exchangeTimezoneName': 'America/New_York',
#                                'exchangeTimezoneShortName': 'EDT',
#                                'fiftyDayAverage': 35138.49,
#                                'fiftyDayAverageChange': -1168.0195,
#                                'fiftyDayAverageChangePercent': -0.03324046,
#                                'fiftyTwoWeekHigh': 35631.19,
#                                'fiftyTwoWeekHighChange': -1660.7227,
#                                'fiftyTwoWeekHighChangePercent': -0.046608675,
#                                'fiftyTwoWeekLow': 26143.77,
#                                'fiftyTwoWeekLowChange': 7826.699,
#                                'fiftyTwoWeekLowChangePercent': 0.29937148,
#                                'fiftyTwoWeekRange': '26143.77 - 35631.19',
#                                'firstTradeDateMilliseconds': 694362600000,
#                                'fullExchangeName': 'DJI',
#                                'gmtOffSetMilliseconds': -14400000,
#                                'language': 'en-US',
#                                'market': 'us_market',
#                                'marketState': 'POST',
#                                'messageBoardId': 'finmb_INDEXDJI',
#                                'priceHint': 2,
#                                'quoteSourceName': 'Delayed Quote',
#                                'quoteType': 'INDEX',
#                                'region': 'US',
#                                'regularMarketChange': -614.41016,
#                                'regularMarketChangePercent': -1.7765284,
#                                'regularMarketDayHigh': 34459.72,
#                                'regularMarketDayLow': 33613.03,
#                                'regularMarketDayRange': '33613.03 - 34459.72',
#                                'regularMarketOpen': 34459.72,
#                                'regularMarketPreviousClose': 34584.88,
#                                'regularMarketPrice': 33970.47,
#                                'regularMarketTime': 1632172142,
#                                'regularMarketVolume': 441645657,
#                                'shortName': 'Dow Jones Industrial Average',
#                                'sourceInterval': 120,
#                                'symbol': '^DJI',
#                                'tradeable': False,
#                                'triggerable': True,
#                                'twoHundredDayAverage': 34242.938,
#                                'twoHundredDayAverageChange': -272.46875,
#                                'twoHundredDayAverageChangePercent': -0.007956932},
#                               {'ask': 151.49,
#                                'askSize': 9,
#                                'averageAnalystRating': '1.8 - Buy',
#                                'averageDailyVolume10Day': 22179833,
#                                'averageDailyVolume3Month': 23562712,
#                                'bid': 151.3,
#                                'bidSize': 14,
#                                'bookValue': 358.74,
#                                'currency': 'USD',
#                                'displayName': 'Alibaba Group Holding',
#                                'earningsTimestamp': 1627993800,
#                                'earningsTimestampEnd': 1636374600,
#                                'earningsTimestampStart': 1635942600,
#                                'epsCurrentYear': 9.72,
#                                'epsForward': 11.29,
#                                'epsTrailingTwelveMonths': 8.318,
#                                'esgPopulated': False,
#                                'exchange': 'NYQ',
#                                'exchangeDataDelayedBy': 0,
#                                'exchangeTimezoneName': 'America/New_York',
#                                'exchangeTimezoneShortName': 'EDT',
#                                'fiftyDayAverage': 175.28589,
#                                'fiftyDayAverageChange': -23.795883,
#                                'fiftyDayAverageChangePercent': -0.1357547,
#                                'fiftyTwoWeekHigh': 319.32,
#                                'fiftyTwoWeekHighChange': -167.83,
#                                'fiftyTwoWeekHighChangePercent': -0.5255856,
#                                'fiftyTwoWeekLow': 149.09,
#                                'fiftyTwoWeekLowChange': 2.4000092,
#                                'fiftyTwoWeekLowChangePercent': 0.01609772,
#                                'fiftyTwoWeekRange': '149.09 - 319.32',
#                                'financialCurrency': 'CNY',
#                                'firstTradeDateMilliseconds': 1411133400000,
#                                'forwardPE': 13.41807,
#                                'fullExchangeName': 'NYSE',
#                                'gmtOffSetMilliseconds': -14400000,
#                                'language': 'en-US',
#                                'longName': 'Alibaba Group Holding Limited',
#                                'market': 'us_market',
#                                'marketCap': 410675773440,
#                                'marketState': 'POST',
#                                'messageBoardId': 'finmb_42083601',
#                                'postMarketChange': 0.07499695,
#                                'postMarketChangePercent': 0.049506202,
#                                'postMarketPrice': 151.565,
#                                'postMarketTime': 1632174047,
#                                'priceEpsCurrentYear': 15.585391,
#                                'priceHint': 2,
#                                'priceToBook': 0.42228356,
#                                'quoteSourceName': 'Nasdaq Real Time Price',
#                                'quoteType': 'EQUITY',
#                                'region': 'US',
#                                'regularMarketChange': -8.56,
#                                'regularMarketChangePercent': -5.34833,
#                                'regularMarketDayHigh': 155.14,
#                                'regularMarketDayLow': 149.09,
#                                'regularMarketDayRange': '149.09 - 155.14',
#                                'regularMarketOpen': 154.4,
#                                'regularMarketPreviousClose': 160.05,
#                                'regularMarketPrice': 151.49,
#                                'regularMarketTime': 1632168002,
#                                'regularMarketVolume': 34945711,
#                                'sharesOutstanding': 2710909952,
#                                'shortName': 'Alibaba Group Holding Limited',
#                                'sourceInterval': 15,
#                                'symbol': 'BABA',
#                                'tradeable': False,
#                                'trailingPE': 18.21231,
#                                'triggerable': True,
#                                'twoHundredDayAverage': 209.69588,
#                                'twoHundredDayAverageChange': -58.20587,
#                                'twoHundredDayAverageChangePercent': -0.2775728},
#                               {'ask': 4.4,
#                                'askSize': 18,
#                                'averageDailyVolume10Day': 46550,
#                                'averageDailyVolume3Month': 218658,
#                                'bid': 4.7,
#                                'bidSize': 10,
#                                'bookValue': 0.809,
#                                'currency': 'USD',
#                                'displayName': 'ZIVO Bioscience',
#                                'epsTrailingTwelveMonths': -1.732,
#                                'esgPopulated': False,
#                                'exchange': 'NCM',
#                                'exchangeDataDelayedBy': 0,
#                                'exchangeTimezoneName': 'America/New_York',
#                                'exchangeTimezoneShortName': 'EDT',
#                                'fiftyDayAverage': 3.2770588,
#                                'fiftyDayAverageChange': 1.382941,
#                                'fiftyDayAverageChangePercent': 0.42200676,
#                                'fiftyTwoWeekHigh': 7.9,
#                                'fiftyTwoWeekHighChange': -3.2400002,
#                                'fiftyTwoWeekHighChangePercent': -0.4101266,
#                                'fiftyTwoWeekLow': 0.08,
#                                'fiftyTwoWeekLowChange': 4.58,
#                                'fiftyTwoWeekLowChangePercent': 57.25,
#                                'fiftyTwoWeekRange': '0.08 - 7.9',
#                                'financialCurrency': 'USD',
#                                'firstTradeDateMilliseconds': 1071498600000,
#                                'fullExchangeName': 'NasdaqCM',
#                                'gmtOffSetMilliseconds': -14400000,
#                                'ipoExpectedDate': '2021-05-28',
#                                'language': 'en-US',
#                                'longName': 'ZIVO Bioscience, Inc.',
#                                'market': 'us_market',
#                                'marketCap': 42958956,
#                                'marketState': 'POST',
#                                'messageBoardId': 'finmb_7337423',
#                                'postMarketChange': -0.5499997,
#                                'postMarketChangePercent': -11.802569,
#                                'postMarketPrice': 4.11,
#                                'postMarketTime': 1632174048,
#                                'priceHint': 4,
#                                'priceToBook': 5.7601976,
#                                'quoteSourceName': 'Nasdaq Real Time Price',
#                                'quoteType': 'EQUITY',
#                                'region': 'US',
#                                'regularMarketChange': 1.8599999,
#                                'regularMarketChangePercent': 66.428566,
#                                'regularMarketDayHigh': 7.9,
#                                'regularMarketDayLow': 4.52,
#                                'regularMarketDayRange': '4.52 - 7.9',
#                                'regularMarketOpen': 5.98,
#                                'regularMarketPreviousClose': 2.8,
#                                'regularMarketPrice': 4.66,
#                                'regularMarketTime': 1632168002,
#                                'regularMarketVolume': 120139140,
#                                'sharesOutstanding': 9218660,
#                                'shortName': 'Zivo Bioscience, Inc.',
#                                'sourceInterval': 15,
#                                'symbol': 'ZIVO',
#                                'tradeable': False,
#                                'triggerable': True,
#                                'twoHundredDayAverage': 2.2150724,
#                                'twoHundredDayAverageChange': 2.4449275,
#                                'twoHundredDayAverageChangePercent': 1.1037686},
#                               {'averageDailyVolume10Day': 32767843516,
#                                'averageDailyVolume3Month': 32510185781,
#                                'circulatingSupply': 18821662,
#                                'coinImageUrl': 'https://s.yimg.com/uc/fin/img/reports-thumbnails/1.png',
#                                'currency': 'USD',
#                                'esgPopulated': False,
#                                'exchange': 'CCC',
#                                'exchangeDataDelayedBy': 0,
#                                'exchangeTimezoneName': 'Europe/London',
#                                'exchangeTimezoneShortName': 'BST',
#                                'fiftyDayAverage': 46515.508,
#                                'fiftyDayAverageChange': -2815.871,
#                                'fiftyDayAverageChangePercent': -0.06053618,
#                                'fiftyTwoWeekHigh': 64863.098,
#                                'fiftyTwoWeekHighChange': -21163.46,
#                                'fiftyTwoWeekHighChangePercent': -0.32627892,
#                                'fiftyTwoWeekLow': 10185.774,
#                                'fiftyTwoWeekLowChange': 33513.863,
#                                'fiftyTwoWeekLowChangePercent': 3.2902617,
#                                'fiftyTwoWeekRange': '10185.774 - 64863.098',
#                                'firstTradeDateMilliseconds': 1410908400000,
#                                'fromCurrency': 'BTC',
#                                'fullExchangeName': 'CCC',
#                                'gmtOffSetMilliseconds': 3600000,
#                                'language': 'en-US',
#                                'lastMarket': 'CoinMarketCap',
#                                'market': 'ccc_market',
#                                'marketCap': 822499803136,
#                                'marketState': 'REGULAR',
#                                'messageBoardId': 'finmb_BTC_CCC',
#                                'priceHint': 2,
#                                'quoteSourceName': 'CoinMarketCap',
#                                'quoteType': 'CRYPTOCURRENCY',
#                                'region': 'US',
#                                'regularMarketChange': -3871.2031,
#                                'regularMarketChangePercent': -8.137768,
#                                'regularMarketDayHigh': 47269.414,
#                                'regularMarketDayLow': 42760.734,
#                                'regularMarketDayRange': '42760.734 - 47269.414',
#                                'regularMarketOpen': 47221.242,
#                                'regularMarketPreviousClose': 47221.242,
#                                'regularMarketPrice': 43699.637,
#                                'regularMarketTime': 1632174002,
#                                'regularMarketVolume': 43229429760,
#                                'shortName': 'Bitcoin USD',
#                                'sourceInterval': 15,
#                                'startDate': 1367103600,
#                                'symbol': 'BTC-USD',
#                                'toCurrency': 'USD=X',
#                                'tradeable': False,
#                                'triggerable': True,
#                                'twoHundredDayAverage': 45906.29,
#                                'twoHundredDayAverageChange': -2206.6523,
#                                'twoHundredDayAverageChangePercent': -0.048068628,
#                                'volume24Hr': 43229429760,
#                                'volumeAllCurrencies': 43229429760},
#                               {'ask': 4406.7,
#                                'askSize': 0,
#                                'averageDailyVolume10Day': 3435710000,
#                                'averageDailyVolume3Month': 3130093015,
#                                'bid': 4298.92,
#                                'bidSize': 0,
#                                'currency': 'USD',
#                                'esgPopulated': False,
#                                'exchange': 'SNP',
#                                'exchangeDataDelayedBy': 0,
#                                'exchangeTimezoneName': 'America/New_York',
#                                'exchangeTimezoneShortName': 'EDT',
#                                'fiftyDayAverage': 4466.533,
#                                'fiftyDayAverageChange': -108.80322,
#                                'fiftyDayAverageChangePercent': -0.024359658,
#                                'fiftyTwoWeekHigh': 4545.85,
#                                'fiftyTwoWeekHighChange': -188.12012,
#                                'fiftyTwoWeekHighChangePercent': -0.041382823,
#                                'fiftyTwoWeekLow': 3209.45,
#                                'fiftyTwoWeekLowChange': 1148.28,
#                                'fiftyTwoWeekLowChangePercent': 0.35778093,
#                                'fiftyTwoWeekRange': '3209.45 - 4545.85',
#                                'firstTradeDateMilliseconds': -1325583000000,
#                                'fullExchangeName': 'SNP',
#                                'gmtOffSetMilliseconds': -14400000,
#                                'language': 'en-US',
#                                'market': 'us_market',
#                                'marketState': 'POST',
#                                'messageBoardId': 'finmb_INDEXGSPC',
#                                'priceHint': 2,
#                                'quoteSourceName': 'Delayed Quote',
#                                'quoteType': 'INDEX',
#                                'region': 'US',
#                                'regularMarketChange': -75.260254,
#                                'regularMarketChangePercent': -1.697731,
#                                'regularMarketDayHigh': 4402.95,
#                                'regularMarketDayLow': 4305.91,
#                                'regularMarketDayRange': '4305.91 - 4402.95',
#                                'regularMarketOpen': 4402.95,
#                                'regularMarketPreviousClose': 4432.99,
#                                'regularMarketPrice': 4357.73,
#                                'regularMarketTime': 1632172142,
#                                'regularMarketVolume': 2598257000,
#                                'shortName': 'S&P 500',
#                                'sourceInterval': 15,
#                                'symbol': '^GSPC',
#                                'tradeable': False,
#                                'triggerable': True,
#                                'twoHundredDayAverage': 4242.1626,
#                                'twoHundredDayAverageChange': 115.56738,
#                                'twoHundredDayAverageChangePercent': 0.027242564},
#                               {'ask': 11.86,
#                                'askSize': 13,
#                                'averageDailyVolume10Day': 76200,
#                                'averageDailyVolume3Month': 65790,
#                                'bid': 11.89,
#                                'bidSize': 13,
#                                'bookValue': 1.192,
#                                'currency': 'USD',
#                                'displayName': 'Edesa Biotech',
#                                'dividendDate': 1560124800,
#                                'earningsTimestamp': 1628857800,
#                                'earningsTimestampEnd': 1639143000,
#                                'earningsTimestampStart': 1638797400,
#                                'epsCurrentYear': -1.17,
#                                'epsForward': -1.33,
#                                'epsTrailingTwelveMonths': -1.052,
#                                'esgPopulated': False,
#                                'exchange': 'NCM',
#                                'exchangeDataDelayedBy': 0,
#                                'exchangeTimezoneName': 'America/New_York',
#                                'exchangeTimezoneShortName': 'EDT',
#                                'fiftyDayAverage': 5.075,
#                                'fiftyDayAverageChange': 6.8450003,
#                                'fiftyDayAverageChangePercent': 1.3487686,
#                                'fiftyTwoWeekHigh': 12.0,
#                                'fiftyTwoWeekHighChange': -0.07999992,
#                                'fiftyTwoWeekHighChangePercent': -0.0066666603,
#                                'fiftyTwoWeekLow': 4.05,
#                                'fiftyTwoWeekLowChange': 7.87,
#                                'fiftyTwoWeekLowChangePercent': 1.9432098,
#                                'fiftyTwoWeekRange': '4.05 - 12.0',
#                                'financialCurrency': 'USD',
#                                'firstTradeDateMilliseconds': 1277127000000,
#                                'forwardPE': -8.962406,
#                                'fullExchangeName': 'NasdaqCM',
#                                'gmtOffSetMilliseconds': -14400000,
#                                'language': 'en-US',
#                                'longName': 'Edesa Biotech, Inc.',
#                                'market': 'us_market',
#                                'marketCap': 158006752,
#                                'marketState': 'POST',
#                                'messageBoardId': 'finmb_313039720',
#                                'postMarketChange': -2.29,
#                                'postMarketChangePercent': -19.211409,
#                                'postMarketPrice': 9.63,
#                                'postMarketTime': 1632174050,
#                                'priceEpsCurrentYear': -10.188035,
#                                'priceHint': 2,
#                                'priceToBook': 10.0,
#                                'quoteSourceName': 'Nasdaq Real Time Price',
#                                'quoteType': 'EQUITY',
#                                'region': 'US',
#                                'regularMarketChange': 6.04,
#                                'regularMarketChangePercent': 102.721085,
#                                'regularMarketDayHigh': 12.0,
#                                'regularMarketDayLow': 7.47,
#                                'regularMarketDayRange': '7.47 - 12.0',
#                                'regularMarketOpen': 9.45,
#                                'regularMarketPreviousClose': 5.88,
#                                'regularMarketPrice': 11.92,
#                                'regularMarketTime': 1632168003,
#                                'regularMarketVolume': 154286072,
#                                'sharesOutstanding': 13255600,
#                                'shortName': 'Edesa Biotech, Inc.',
#                                'sourceInterval': 15,
#                                'symbol': 'EDSA',
#                                'tradeable': False,
#                                'triggerable': True,
#                                'twoHundredDayAverage': 5.452971,
#                                'twoHundredDayAverageChange': 6.467029,
#                                'twoHundredDayAverageChangePercent': 1.1859643},
#                               {'ask': 0.0,
#                                'askSize': 0,
#                                'averageDailyVolume10Day': 4775290000,
#                                'averageDailyVolume3Month': 4251811111,
#                                'bid': 0.0,
#                                'bidSize': 0,
#                                'currency': 'USD',
#                                'esgPopulated': False,
#                                'exchange': 'NIM',
#                                'exchangeDataDelayedBy': 0,
#                                'exchangeTimezoneName': 'America/New_York',
#                                'exchangeTimezoneShortName': 'EDT',
#                                'fiftyDayAverage': 14982.439,
#                                'fiftyDayAverageChange': -268.53613,
#                                'fiftyDayAverageChangePercent': -0.017923392,
#                                'fiftyTwoWeekHigh': 15403.44,
#                                'fiftyTwoWeekHighChange': -689.5371,
#                                'fiftyTwoWeekHighChangePercent': -0.044765137,
#                                'fiftyTwoWeekLow': 10519.49,
#                                'fiftyTwoWeekLowChange': 4194.413,
#                                'fiftyTwoWeekLowChangePercent': 0.39872777,
#                                'fiftyTwoWeekRange': '10519.49 - 15403.44',
#                                'firstTradeDateMilliseconds': 34612200000,
#                                'fullExchangeName': 'Nasdaq GIDS',
#                                'gmtOffSetMilliseconds': -14400000,
#                                'language': 'en-US',
#                                'market': 'us_market',
#                                'marketState': 'POST',
#                                'messageBoardId': 'finmb_INDEXIXIC',
#                                'priceHint': 2,
#                                'quoteSourceName': 'Delayed Quote',
#                                'quoteType': 'INDEX',
#                                'region': 'US',
#                                'regularMarketChange': -330.06445,
#                                'regularMarketChangePercent': -2.1939986,
#                                'regularMarketDayHigh': 14841.815,
#                                'regularMarketDayLow': 14530.073,
#                                'regularMarketDayRange': '14530.073 - 14841.815',
#                                'regularMarketOpen': 14758.1,
#                                'regularMarketPreviousClose': 15043.968,
#                                'regularMarketPrice': 14713.903,
#                                'regularMarketTime': 1632172559,
#                                'regularMarketVolume': 4350941000,
#                                'shortName': 'NASDAQ Composite',
#                                'sourceInterval': 15,
#                                'symbol': '^IXIC',
#                                'tradeable': False,
#                                'triggerable': True,
#                                'twoHundredDayAverage': 14146.466,
#                                'twoHundredDayAverageChange': 567.4375,
#                                'twoHundredDayAverageChangePercent': 0.04011161},
#                               {'ask': 3356.8,
#                                'askSize': 11,
#                                'averageAnalystRating': '1.7 - Buy',
#                                'averageDailyVolume10Day': 2842400,
#                                'averageDailyVolume3Month': 3256863,
#                                'bid': 3353.3,
#                                'bidSize': 8,
#                                'bookValue': 226.883,
#                                'currency': 'USD',
#                                'displayName': 'Amazon.com',
#                                'earningsTimestamp': 1627574460,
#                                'earningsTimestampEnd': 1635768000,
#                                'earningsTimestampStart': 1635332340,
#                                'epsCurrentYear': 53.38,
#                                'epsForward': 67.31,
#                                'epsTrailingTwelveMonths': 57.395,
#                                'esgPopulated': False,
#                                'exchange': 'NMS',
#                                'exchangeDataDelayedBy': 0,
#                                'exchangeTimezoneName': 'America/New_York',
#                                'exchangeTimezoneShortName': 'EDT',
#                                'fiftyDayAverage': 3371.3582,
#                                'fiftyDayAverageChange': -15.628174,
#                                'fiftyDayAverageChangePercent': -0.004635572,
#                                'fiftyTwoWeekHigh': 3773.08,
#                                'fiftyTwoWeekHighChange': -417.3501,
#                                'fiftyTwoWeekHighChangePercent': -0.11061257,
#                                'fiftyTwoWeekLow': 2871.0,
#                                'fiftyTwoWeekLowChange': 484.72998,
#                                'fiftyTwoWeekLowChangePercent': 0.16883664,
#                                'fiftyTwoWeekRange': '2871.0 - 3773.08',
#                                'financialCurrency': 'USD',
#                                'firstTradeDateMilliseconds': 863703000000,
#                                'forwardPE': 49.85485,
#                                'fullExchangeName': 'NasdaqGS',
#                                'gmtOffSetMilliseconds': -14400000,
#                                'language': 'en-US',
#                                'longName': 'Amazon.com, Inc.',
#                                'market': 'us_market',
#                                'marketCap': 1699479158784,
#                                'marketState': 'POST',
#                                'messageBoardId': 'finmb_18749',
#                                'postMarketChange': 0.47998,
#                                'postMarketChangePercent': 0.0143033,
#                                'postMarketPrice': 3356.21,
#                                'postMarketTime': 1632174032,
#                                'priceEpsCurrentYear': 62.86493,
#                                'priceHint': 2,
#                                'priceToBook': 14.790575,
#                                'quoteSourceName': 'Nasdaq Real Time Price',
#                                'quoteType': 'EQUITY',
#                                'region': 'US',
#                                'regularMarketChange': -106.79004,
#                                'regularMarketChangePercent': -3.084171,
#                                'regularMarketDayHigh': 3419.0,
#                                'regularMarketDayLow': 3305.01,
#                                'regularMarketDayRange': '3305.01 - 3419.0',
#                                'regularMarketOpen': 3396.0,
#                                'regularMarketPreviousClose': 3462.52,
#                                'regularMarketPrice': 3355.73,
#                                'regularMarketTime': 1632168002,
#                                'regularMarketVolume': 4491167,
#                                'sharesOutstanding': 506440992,
#                                'shortName': 'Amazon.com, Inc.',
#                                'sourceInterval': 15,
#                                'symbol': 'AMZN',
#                                'tradeable': False,
#                                'trailingPE': 58.46729,
#                                'triggerable': True,
#                                'twoHundredDayAverage': 3342.737,
#                                'twoHundredDayAverageChange': 12.99292,
#                                'twoHundredDayAverageChangePercent': 0.0038869106},
#                               {'ask': 0.0,
#                                'askSize': 0,
#                                'averageDailyVolume10Day': 0,
#                                'averageDailyVolume3Month': 0,
#                                'bid': 0.0,
#                                'bidSize': 0,
#                                'currency': 'USD',
#                                'esgPopulated': False,
#                                'exchange': 'WCB',
#                                'exchangeDataDelayedBy': 20,
#                                'exchangeTimezoneName': 'America/New_York',
#                                'exchangeTimezoneShortName': 'EDT',
#                                'fiftyDayAverage': 17.817648,
#                                'fiftyDayAverageChange': 7.892351,
#                                'fiftyDayAverageChangePercent': 0.44295135,
#                                'fiftyTwoWeekHigh': 41.16,
#                                'fiftyTwoWeekHighChange': -15.450001,
#                                'fiftyTwoWeekHighChangePercent': -0.37536445,
#                                'fiftyTwoWeekLow': 14.1,
#                                'fiftyTwoWeekLowChange': 11.609999,
#                                'fiftyTwoWeekLowChangePercent': 0.82340413,
#                                'fiftyTwoWeekRange': '14.1 - 41.16',
#                                'firstTradeDateMilliseconds': 631290600000,
#                                'fullExchangeName': 'Chicago Options',
#                                'gmtOffSetMilliseconds': -14400000,
#                                'language': 'en-US',
#                                'market': 'us_market',
#                                'marketState': 'POST',
#                                'messageBoardId': 'finmb_INDEXVIX',
#                                'priceHint': 2,
#                                'quoteType': 'INDEX',
#                                'region': 'US',
#                                'regularMarketChange': 4.8999996,
#                                'regularMarketChangePercent': 23.546371,
#                                'regularMarketDayHigh': 28.79,
#                                'regularMarketDayLow': 23.9,
#                                'regularMarketDayRange': '23.9 - 28.79',
#                                'regularMarketOpen': 24.25,
#                                'regularMarketPreviousClose': 20.81,
#                                'regularMarketPrice': 25.71,
#                                'regularMarketTime': 1632168890,
#                                'regularMarketVolume': 0,
#                                'shortName': 'CBOE Volatility Index',
#                                'sourceInterval': 15,
#                                'symbol': '^VIX',
#                                'tradeable': False,
#                                'triggerable': True,
#                                'twoHundredDayAverage': 18.38942,
#                                'twoHundredDayAverageChange': 7.3205795,
#                                'twoHundredDayAverageChangePercent': 0.3980865},
#                               {'ask': 68.0,
#                                'askSize': 18,
#                                'averageDailyVolume10Day': 6233,
#                                'averageDailyVolume3Month': 3573,
#                                'bid': 61.0,
#                                'bidSize': 11,
#                                'bookValue': 17.603,
#                                'currency': 'USD',
#                                'epsTrailingTwelveMonths': 1.667,
#                                'esgPopulated': False,
#                                'exchange': 'NMS',
#                                'exchangeDataDelayedBy': 0,
#                                'exchangeTimezoneName': 'America/New_York',
#                                'exchangeTimezoneShortName': 'EDT',
#                                'fiftyDayAverage': 44.98294,
#                                'fiftyDayAverageChange': 22.51706,
#                                'fiftyDayAverageChangePercent': 0.50056887,
#                                'fiftyTwoWeekHigh': 150.72,
#                                'fiftyTwoWeekHighChange': -83.22,
#                                'fiftyTwoWeekHighChangePercent': -0.5521497,
#                                'fiftyTwoWeekLow': 26.0,
#                                'fiftyTwoWeekLowChange': 41.5,
#                                'fiftyTwoWeekLowChangePercent': 1.5961539,
#                                'fiftyTwoWeekRange': '26.0 - 150.72',
#                                'financialCurrency': 'USD',
#                                'firstTradeDateMilliseconds': 1131633000000,
#                                'fullExchangeName': 'NasdaqGS',
#                                'gmtOffSetMilliseconds': -14400000,
#                                'language': 'en-US',
#                                'longName': 'Discovery, Inc.',
#                                'market': 'us_market',
#                                'marketCap': 19529099264,
#                                'marketState': 'POST',
#                                'messageBoardId': 'finmb_22666093',
#                                'postMarketChange': 0.470001,
#                                'postMarketChangePercent': 0.696298,
#                                'postMarketPrice': 67.97,
#                                'postMarketTime': 1632173693,
#                                'priceHint': 2,
#                                'priceToBook': 3.8345735,
#                                'quoteSourceName': 'Nasdaq Real Time Price',
#                                'quoteType': 'EQUITY',
#                                'region': 'US',
#                                'regularMarketChange': 21.099998,
#                                'regularMarketChangePercent': 45.474133,
#                                'regularMarketDayHigh': 67.5,
#                                'regularMarketDayLow': 43.31,
#                                'regularMarketDayRange': '43.31 - 67.5',
#                                'regularMarketOpen': 46.8,
#                                'regularMarketPreviousClose': 46.4,
#                                'regularMarketPrice': 67.5,
#                                'regularMarketTime': 1632168001,
#                                'regularMarketVolume': 22145,
#                                'sharesOutstanding': 6512380,
#                                'shortName': 'Discovery, Inc. - Series B',
#                                'sourceInterval': 15,
#                                'symbol': 'DISCB',
#                                'tradeable': False,
#                                'trailingPE': 40.4919,
#                                'triggerable': True,
#                                'twoHundredDayAverage': 64.96022,
#                                'twoHundredDayAverageChange': 2.5397797,
#                                'twoHundredDayAverageChangePercent': 0.03909746}]}}

# %%
## How many records did we get?
len(response2['quoteResponse']['result'])
# Out:
# 10

# %%
# Create a new DataFrame from all the results in the dictionary
response2_df = pd.DataFrame(response2['quoteResponse']['result'])
response2_df
# Out:
#   language region       quoteType         quoteSourceName  triggerable  \
# 0    en-US     US           INDEX           Delayed Quote         True
# 1    en-US     US          EQUITY  Nasdaq Real Time Price         True
# 2    en-US     US          EQUITY  Nasdaq Real Time Price         True
# 3    en-US     US  CRYPTOCURRENCY           CoinMarketCap         True
# 4    en-US     US           INDEX           Delayed Quote         True
# 5    en-US     US          EQUITY  Nasdaq Real Time Price         True
# 6    en-US     US           INDEX           Delayed Quote         True
# 7    en-US     US          EQUITY  Nasdaq Real Time Price         True
# 8    en-US     US           INDEX                     NaN         True
# 9    en-US     US          EQUITY  Nasdaq Real Time Price         True
#
#   currency  fiftyDayAverage  fiftyDayAverageChange  \
# 0      USD     35138.490000           -1168.019500
# 1      USD       175.285890             -23.795883
# 2      USD         3.277059               1.382941
# 3      USD     46515.508000           -2815.871000
# 4      USD      4466.533000            -108.803220
# 5      USD         5.075000               6.845000
# 6      USD     14982.439000            -268.536130
# 7      USD      3371.358200             -15.628174
# 8      USD        17.817648               7.892351
# 9      USD        44.982940              22.517060
#
#    fiftyDayAverageChangePercent  twoHundredDayAverage  ...  ipoExpectedDate  \
# 0                     -0.033240          34242.938000  ...              NaN
# 1                     -0.135755            209.695880  ...              NaN
# 2                      0.422007              2.215072  ...       2021-05-28
# 3                     -0.060536          45906.290000  ...              NaN
# 4                     -0.024360           4242.162600  ...              NaN
# 5                      1.348769              5.452971  ...              NaN
# 6                     -0.017923          14146.466000  ...              NaN
# 7                     -0.004636           3342.737000  ...              NaN
# 8                      0.442951             18.389420  ...              NaN
# 9                      0.500569             64.960220  ...              NaN
#
#    circulatingSupply     lastMarket    volume24Hr  volumeAllCurrencies  \
# 0                NaN            NaN           NaN                  NaN
# 1                NaN            NaN           NaN                  NaN
# 2                NaN            NaN           NaN                  NaN
# 3         18821662.0  CoinMarketCap  4.322943e+10         4.322943e+10
# 4                NaN            NaN           NaN                  NaN
# 5                NaN            NaN           NaN                  NaN
# 6                NaN            NaN           NaN                  NaN
# 7                NaN            NaN           NaN                  NaN
# 8                NaN            NaN           NaN                  NaN
# 9                NaN            NaN           NaN                  NaN
#
#   fromCurrency toCurrency     startDate  \
# 0          NaN        NaN           NaN
# 1          NaN        NaN           NaN
# 2          NaN        NaN           NaN
# 3          BTC      USD=X  1.367104e+09
# 4          NaN        NaN           NaN
# 5          NaN        NaN           NaN
# 6          NaN        NaN           NaN
# 7          NaN        NaN           NaN
# 8          NaN        NaN           NaN
# 9          NaN        NaN           NaN
#
#                                         coinImageUrl  dividendDate
# 0                                                NaN           NaN
# 1                                                NaN           NaN
# 2                                                NaN           NaN
# 3  https://s.yimg.com/uc/fin/img/reports-thumbnai...           NaN
# 4                                                NaN           NaN
# 5                                                NaN  1.560125e+09
# 6                                                NaN           NaN
# 7                                                NaN           NaN
# 8                                                NaN           NaN
# 9                                                NaN           NaN
#
# [10 rows x 82 columns]

# %% [markdown]
# # 3. STOCK HISTORY
#
# API domain: https://yfapi.net
# API path: /v8/finance/spark
# API variables:  querystring  {"symbols" : "string1,string2,string3,..."}
#                 interval  (1 minute to 1 month)
#                 range     (1 day to 1 month to 5 years)
#
# Pull data (extract) from yahoofinancials API (URL path is /v8/finance/spark) with "symbols" set to comma-separated list of up to 10 stock symbols at a time.  Specify data interval and range of desired time span.
#
# Use the query_string of 10 stock symbols.  Returns

# %%
## Query of /v8/finance/spark API

url = "https://yfapi.net/v8/finance/spark"
## Alternate url
# url = "https://rest.yahoofinanceapi.com/v8/finance/spark"

## Warning: no space between symbols
my_interval = "1d"
my_range = "1mo"
querystring = {"symbols" : query_string,
               "interval": my_interval,
               "range"   : my_range
              }

# Credentials to include
headers = {
    'x-api-key': API_KEY
    }

# %%
## Make API request (query string required for this API)
response3 = requests.request("GET", url, headers=headers, params=querystring).json()

# What does the response look like?  We will have to use indexing to get to the 'result' level
pprint.pprint(response3)
# Out:
# {'AMZN': {'chartPreviousClose': 3199.95,
#           'close': [3265.87,
#                     3305.78,
#                     3299.18,
#                     3316.0,
#                     3349.63,
#                     3421.57,
#                     3470.79,
#                     3479.0,
#                     3463.12,
#                     3478.05,
#                     3509.29,
#                     3525.5,
#                     3484.16,
#                     3469.15,
#                     3457.17,
#                     3450.0,
#                     3475.79,
#                     3488.24,
#                     3462.52,
#                     3355.73],
#           'dataGranularity': 300,
#           'end': None,
#           'previousClose': None,
#           'start': None,
#           'symbol': 'AMZN',
#           'timestamp': [1629725400,
#                         1629811800,
#                         1629898200,
#                         1629984600,
#                         1630071000,
#                         1630330200,
#                         1630416600,
#                         1630503000,
#                         1630589400,
#                         1630675800,
#                         1631021400,
#                         1631107800,
#                         1631194200,
#                         1631280600,
#                         1631539800,
#                         1631626200,
#                         1631712600,
#                         1631799000,
#                         1631885400,
#                         1632168002]},
#  'BABA': {'chartPreviousClose': 157.96,
#           'close': [161.06,
#                     171.7,
#                     169.1,
#                     165.24,
#                     159.47,
#                     162.29,
#                     166.99,
#                     173.28,
#                     172.0,
#                     170.3,
#                     175.16,
#                     170.71,
#                     167.32,
#                     168.1,
#                     165.41,
#                     160.15,
#                     157.86,
#                     156.26,
#                     160.05,
#                     151.49],
#           'dataGranularity': 300,
#           'end': None,
#           'previousClose': None,
#           'start': None,
#           'symbol': 'BABA',
#           'timestamp': [1629725400,
#                         1629811800,
#                         1629898200,
#                         1629984600,
#                         1630071000,
#                         1630330200,
#                         1630416600,
#                         1630503000,
#                         1630589400,
#                         1630675800,
#                         1631021400,
#                         1631107800,
#                         1631194200,
#                         1631280600,
#                         1631539800,
#                         1631626200,
#                         1631712600,
#                         1631799000,
#                         1631885400,
#                         1632168002]},
#  'BTC-USD': {'chartPreviousClose': 49339.176,
#              'close': [49339.176,
#                        48905.492,
#                        49321.652,
#                        49546.15,
#                        47706.117,
#                        48960.79,
#                        46942.22,
#                        49058.668,
#                        48902.402,
#                        48829.832,
#                        47054.984,
#                        47166.688,
#                        48847.027,
#                        49327.723,
#                        50025.375,
#                        49944.625,
#                        51753.41,
#                        52633.535,
#                        46811.13,
#                        46091.39,
#                        46391.42,
#                        44883.91,
#                        45201.457,
#                        46063.27,
#                        44963.074,
#                        47092.492,
#                        48176.348,
#                        47783.36,
#                        47267.52,
#                        48278.363,
#                        47260.22,
#                        43699.637],
#              'dataGranularity': 300,
#              'end': None,
#              'previousClose': None,
#              'start': None,
#              'symbol': 'BTC-USD',
#              'timestamp': [1629414000,
#                            1629500400,
#                            1629586800,
#                            1629673200,
#                            1629759600,
#                            1629846000,
#                            1629932400,
#                            1630018800,
#                            1630105200,
#                            1630191600,
#                            1630278000,
#                            1630364400,
#                            1630450800,
#                            1630537200,
#                            1630623600,
#                            1630710000,
#                            1630796400,
#                            1630882800,
#                            1630969200,
#                            1631055600,
#                            1631142000,
#                            1631228400,
#                            1631314800,
#                            1631401200,
#                            1631487600,
#                            1631574000,
#                            1631660400,
#                            1631746800,
#                            1631833200,
#                            1631919600,
#                            1632006000,
#                            1632174002]},
#  'DISCB': {'chartPreviousClose': 38.17,
#            'close': [39.34,
#                      40.73,
#                      44.39,
#                      43.13,
#                      43.07,
#                      50.83,
#                      50.02,
#                      49.51,
#                      48.5,
#                      49.54,
#                      49.0,
#                      46.31,
#                      46.4,
#                      44.85,
#                      46.45,
#                      44.84,
#                      43.8,
#                      44.73,
#                      46.4,
#                      67.5],
#            'dataGranularity': 300,
#            'end': None,
#            'previousClose': None,
#            'start': None,
#            'symbol': 'DISCB',
#            'timestamp': [1629725400,
#                          1629811800,
#                          1629898200,
#                          1629984600,
#                          1630071000,
#                          1630330200,
#                          1630416600,
#                          1630503000,
#                          1630589400,
#                          1630675800,
#                          1631021400,
#                          1631107800,
#                          1631194200,
#                          1631280600,
#                          1631539800,
#                          1631626200,
#                          1631712600,
#                          1631799000,
#                          1631885400,
#                          1632168001]},
#  'EDSA': {'chartPreviousClose': 4.2,
#           'close': [4.35,
#                     4.46,
#                     4.68,
#                     4.93,
#                     5.01,
#                     5.2,
#                     5.87,
#                     6.12,
#                     5.84,
#                     5.8,
#                     5.73,
#                     5.84,
#                     5.79,
#                     5.93,
#                     5.74,
#                     5.5,
#                     5.45,
#                     5.58,
#                     5.88,
#                     11.92],
#           'dataGranularity': 300,
#           'end': None,
#           'previousClose': None,
#           'start': None,
#           'symbol': 'EDSA',
#           'timestamp': [1629725400,
#                         1629811800,
#                         1629898200,
#                         1629984600,
#                         1630071000,
#                         1630330200,
#                         1630416600,
#                         1630503000,
#                         1630589400,
#                         1630675800,
#                         1631021400,
#                         1631107800,
#                         1631194200,
#                         1631280600,
#                         1631539800,
#                         1631626200,
#                         1631712600,
#                         1631799000,
#                         1631885400,
#                         1632168003]},
#  'ZIVO': {'chartPreviousClose': 3.2,
#           'close': [3.39,
#                     3.27,
#                     3.25,
#                     3.23,
#                     3.24,
#                     3.18,
#                     3.14,
#                     3.36,
#                     3.21,
#                     3.48,
#                     3.33,
#                     3.5,
#                     3.49,
#                     3.45,
#                     3.51,
#                     3.29,
#                     3.36,
#                     2.8,
#                     4.66],
#           'dataGranularity': 300,
#           'end': None,
#           'previousClose': None,
#           'start': None,
#           'symbol': 'ZIVO',
#           'timestamp': [1629725400,
#                         1629811800,
#                         1629984600,
#                         1630071000,
#                         1630330200,
#                         1630416600,
#                         1630503000,
#                         1630589400,
#                         1630675800,
#                         1631021400,
#                         1631107800,
#                         1631194200,
#                         1631280600,
#                         1631539800,
#                         1631626200,
#                         1631712600,
#                         1631799000,
#                         1631885400,
#                         1632168002]},
#  '^DJI': {'chartPreviousClose': 35120.08,
#           'close': [35335.71,
#                     35366.26,
#                     35405.5,
#                     35213.12,
#                     35455.8,
#                     35399.84,
#                     35360.73,
#                     35312.53,
#                     35443.82,
#                     35369.09,
#                     35100.0,
#                     35031.07,
#                     34879.38,
#                     34607.72,
#                     34869.63,
#                     34577.57,
#                     34814.39,
#                     34751.32,
#                     34584.88,
#                     33970.47],
#           'dataGranularity': 300,
#           'end': None,
#           'previousClose': None,
#           'start': None,
#           'symbol': '^DJI',
#           'timestamp': [1629725400,
#                         1629811800,
#                         1629898200,
#                         1629984600,
#                         1630071000,
#                         1630330200,
#                         1630416600,
#                         1630503000,
#                         1630589400,
#                         1630675800,
#                         1631021400,
#                         1631107800,
#                         1631194200,
#                         1631280600,
#                         1631539800,
#                         1631626200,
#                         1631712600,
#                         1631799000,
#                         1631885400,
#                         1632172142]},
#  '^GSPC': {'chartPreviousClose': 4441.67,
#            'close': [4479.53,
#                      4486.23,
#                      4496.19,
#                      4470.0,
#                      4509.37,
#                      4528.79,
#                      4522.68,
#                      4524.09,
#                      4536.95,
#                      4535.43,
#                      4520.03,
#                      4514.07,
#                      4493.28,
#                      4458.58,
#                      4468.73,
#                      4443.05,
#                      4480.7,
#                      4473.75,
#                      4432.99,
#                      4357.73],
#            'dataGranularity': 300,
#            'end': None,
#            'previousClose': None,
#            'start': None,
#            'symbol': '^GSPC',
#            'timestamp': [1629725400,
#                          1629811800,
#                          1629898200,
#                          1629984600,
#                          1630071000,
#                          1630330200,
#                          1630416600,
#                          1630503000,
#                          1630589400,
#                          1630675800,
#                          1631021400,
#                          1631107800,
#                          1631194200,
#                          1631280600,
#                          1631539800,
#                          1631626200,
#                          1631712600,
#                          1631799000,
#                          1631885400,
#                          1632172142]},
#  '^IXIC': {'chartPreviousClose': 14714.66,
#            'close': [14942.65,
#                      15019.8,
#                      15041.86,
#                      14945.81,
#                      15129.5,
#                      15265.89,
#                      15259.24,
#                      15309.38,
#                      15331.18,
#                      15363.52,
#                      15374.33,
#                      15286.64,
#                      15248.25,
#                      15115.49,
#                      15105.58,
#                      15037.76,
#                      15161.53,
#                      15181.92,
#                      15043.97,
#                      14713.903],
#            'dataGranularity': 300,
#            'end': None,
#            'previousClose': None,
#            'start': None,
#            'symbol': '^IXIC',
#            'timestamp': [1629725400,
#                          1629811800,
#                          1629898200,
#                          1629984600,
#                          1630071000,
#                          1630330200,
#                          1630416600,
#                          1630503000,
#                          1630589400,
#                          1630675800,
#                          1631021400,
#                          1631107800,
#                          1631194200,
#                          1631280600,
#                          1631539800,
#                          1631626200,
#                          1631712600,
#                          1631799000,
#                          1631885400,
#                          1632172559]},
#  '^VIX': {'chartPreviousClose': 18.56,
#           'close': [17.15,
#                     17.22,
#                     16.79,
#                     18.84,
#                     16.39,
#                     16.19,
#                     16.48,
#                     16.11,
#                     16.41,
#                     16.41,
#                     18.14,
#                     17.96,
#                     18.8,
#                     20.95,
#                     19.37,
#                     19.46,
#                     18.18,
#                     18.69,
#                     20.81,
#                     25.71],
#           'dataGranularity': 300,
#           'end': None,
#           'previousClose': None,
#           'start': None,
#           'symbol': '^VIX',
#           'timestamp': [1629725400,
#                         1629811800,
#                         1629898200,
#                         1629984600,
#                         1630071000,
#                         1630330200,
#                         1630416600,
#                         1630503000,
#                         1630589400,
#                         1630675800,
#                         1631021400,
#                         1631107800,
#                         1631194200,
#                         1631280600,
#                         1631539800,
#                         1631626200,
#                         1631712600,
#                         1631799000,
#                         1631885400,
#                         1632168890]}}

# %%
## How many records did we get?
len(response3)
# Out:
# 10

# %%
# Create a new DataFrame from all the results in the dictionary
response3_df = pd.DataFrame(response3)
response3_df
# Out:
#                                                                  BABA  \
# timestamp           [1629725400, 1629811800, 1629898200, 162998460...
# symbol                                                           BABA
# previousClose                                                    None
# chartPreviousClose                                             157.96
# dataGranularity                                                   300
# end                                                              None
# start                                                            None
# close               [161.06, 171.7, 169.1, 165.24, 159.47, 162.29,...
#
#                                                               BTC-USD  \
# timestamp           [1629414000, 1629500400, 1629586800, 162967320...
# symbol                                                        BTC-USD
# previousClose                                                    None
# chartPreviousClose                                          49339.176
# dataGranularity                                                   300
# end                                                              None
# start                                                            None
# close               [49339.176, 48905.492, 49321.652, 49546.15, 47...
#
#                                                                  ZIVO  \
# timestamp           [1629725400, 1629811800, 1629984600, 163007100...
# symbol                                                           ZIVO
# previousClose                                                    None
# chartPreviousClose                                                3.2
# dataGranularity                                                   300
# end                                                              None
# start                                                            None
# close               [3.39, 3.27, 3.25, 3.23, 3.24, 3.18, 3.14, 3.3...
#
#                                                                 ^GSPC  \
# timestamp           [1629725400, 1629811800, 1629898200, 162998460...
# symbol                                                          ^GSPC
# previousClose                                                    None
# chartPreviousClose                                            4441.67
# dataGranularity                                                   300
# end                                                              None
# start                                                            None
# close               [4479.53, 4486.23, 4496.19, 4470.0, 4509.37, 4...
#
#                                                                 ^IXIC  \
# timestamp           [1629725400, 1629811800, 1629898200, 162998460...
# symbol                                                          ^IXIC
# previousClose                                                    None
# chartPreviousClose                                           14714.66
# dataGranularity                                                   300
# end                                                              None
# start                                                            None
# close               [14942.65, 15019.8, 15041.86, 14945.81, 15129....
#
#                                                                  ^VIX  \
# timestamp           [1629725400, 1629811800, 1629898200, 162998460...
# symbol                                                           ^VIX
# previousClose                                                    None
# chartPreviousClose                                              18.56
# dataGranularity                                                   300
# end                                                              None
# start                                                            None
# close               [17.15, 17.22, 16.79, 18.84, 16.39, 16.19, 16....
#
#                                                                  EDSA  \
# timestamp           [1629725400, 1629811800, 1629898200, 162998460...
# symbol                                                           EDSA
# previousClose                                                    None
# chartPreviousClose                                                4.2
# dataGranularity                                                   300
# end                                                              None
# start                                                            None
# close               [4.35, 4.46, 4.68, 4.93, 5.01, 5.2, 5.87, 6.12...
#
#                                                                 DISCB  \
# timestamp           [1629725400, 1629811800, 1629898200, 162998460...
# symbol                                                          DISCB
# previousClose                                                    None
# chartPreviousClose                                              38.17
# dataGranularity                                                   300
# end                                                              None
# start                                                            None
# close               [39.34, 40.73, 44.39, 43.13, 43.07, 50.83, 50....
#
#                                                                  ^DJI  \
# timestamp           [1629725400, 1629811800, 1629898200, 162998460...
# symbol                                                           ^DJI
# previousClose                                                    None
# chartPreviousClose                                           35120.08
# dataGranularity                                                   300
# end                                                              None
# start                                                            None
# close               [35335.71, 35366.26, 35405.5, 35213.12, 35455....
#
#                                                                  AMZN
# timestamp           [1629725400, 1629811800, 1629898200, 162998460...
# symbol                                                           AMZN
# previousClose                                                    None
# chartPreviousClose                                            3199.95
# dataGranularity                                                   300
# end                                                              None
# start                                                            None
# close               [3265.87, 3305.78, 3299.18, 3316.0, 3349.63, 3...

# %%
# Or try to turn the dictionary of dictionaries into a list of dictionaries before
# Feeding it into a dataframe.  Dataframes are best as list of dictionaries.

list3 = []
for value in response3:
    # print(response3[value])
    list3.append(response3[value])
## Alternate syntax with list comprehension
# list3 = [response3[value] for value in response3]
list3[0]
# Out:
# {'timestamp': [1629725400,
#   1629811800,
#   1629898200,
#   1629984600,
#   1630071000,
#   1630330200,
#   1630416600,
#   1630503000,
#   1630589400,
#   1630675800,
#   1631021400,
#   1631107800,
#   1631194200,
#   1631280600,
#   1631539800,
#   1631626200,
#   1631712600,
#   1631799000,
#   1631885400,
#   1632168002],
#  'symbol': 'BABA',
#  'previousClose': None,
#  'chartPreviousClose': 157.96,
#  'dataGranularity': 300,
#  'end': None,
#  'start': None,
#  'close': [161.06,
#   171.7,
#   169.1,
#   165.24,
#   159.47,
#   162.29,
#   166.99,
#   173.28,
#   172.0,
#   170.3,
#   175.16,
#   170.71,
#   167.32,
#   168.1,
#   165.41,
#   160.15,
#   157.86,
#   156.26,
#   160.05,
#   151.49]}

# %%
list3_df = pd.DataFrame(list3)
list3_df
# Out:
#                                            timestamp   symbol previousClose  \
# 0  [1629725400, 1629811800, 1629898200, 162998460...     BABA          None
# 1  [1629414000, 1629500400, 1629586800, 162967320...  BTC-USD          None
# 2  [1629725400, 1629811800, 1629984600, 163007100...     ZIVO          None
# 3  [1629725400, 1629811800, 1629898200, 162998460...    ^GSPC          None
# 4  [1629725400, 1629811800, 1629898200, 162998460...    ^IXIC          None
# 5  [1629725400, 1629811800, 1629898200, 162998460...     ^VIX          None
# 6  [1629725400, 1629811800, 1629898200, 162998460...     EDSA          None
# 7  [1629725400, 1629811800, 1629898200, 162998460...    DISCB          None
# 8  [1629725400, 1629811800, 1629898200, 162998460...     ^DJI          None
# 9  [1629725400, 1629811800, 1629898200, 162998460...     AMZN          None
#
#    chartPreviousClose  dataGranularity   end start  \
# 0             157.960              300  None  None
# 1           49339.176              300  None  None
# 2               3.200              300  None  None
# 3            4441.670              300  None  None
# 4           14714.660              300  None  None
# 5              18.560              300  None  None
# 6               4.200              300  None  None
# 7              38.170              300  None  None
# 8           35120.080              300  None  None
# 9            3199.950              300  None  None
#
#                                                close
# 0  [161.06, 171.7, 169.1, 165.24, 159.47, 162.29,...
# 1  [49339.176, 48905.492, 49321.652, 49546.15, 47...
# 2  [3.39, 3.27, 3.25, 3.23, 3.24, 3.18, 3.14, 3.3...
# 3  [4479.53, 4486.23, 4496.19, 4470.0, 4509.37, 4...
# 4  [14942.65, 15019.8, 15041.86, 14945.81, 15129....
# 5  [17.15, 17.22, 16.79, 18.84, 16.39, 16.19, 16....
# 6  [4.35, 4.46, 4.68, 4.93, 5.01, 5.2, 5.87, 6.12...
# 7  [39.34, 40.73, 44.39, 43.13, 43.07, 50.83, 50....
# 8  [35335.71, 35366.26, 35405.5, 35213.12, 35455....
# 9  [3265.87, 3305.78, 3299.18, 3316.0, 3349.63, 3...

# %% [markdown]
# # 4. Steps beyond
#
# We could save the raw outputs into 3 database tables.
#
# Transformations (either in the database or here in Jupyter Notebook):
# From above, we would probably want another table with the stock symbol, timestamp, and closing price.  Do we need 'time of capture' column?
# For time stamp, we would likely need the Python code that can transform this Unix time stamp into a MM-DD-YYYY format when inputing into PostGres table.  Or we can ingest this field as-is and then in database perform the calculation.
#
# Load (in the database):
# Decide for each raw table above which columns will be needed for the final set of tables.  Make those tables, calculations, etc, and produce the final set of tables.
